# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import os
import config
from joblib import dump, load
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import balanced_accuracy_score, accuracy_score
from utils import confusion
from GMHI import GMHI

# %% [markdown]
# # Load data

# %%
X = pd.read_csv(os.path.join(config.CLEAN_DIR, "taxonomic_features.csv"), index_col=[0, 1])
print(X.shape)
y = pd.read_csv(os.path.join(config.CLEAN_DIR, "metadata.csv"), index_col=[0, 1]).iloc[:, [0]]
display(X.head())
display(y.head())
# Out:
# (8069, 3200)
#                            k__Archaea  k__Archaea|p__Euryarchaeota  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239        0.000000                     0.000000
#          SAMN03283266        0.000000                     0.000000
#          SAMN03283281        0.009764                     0.009764
#          SAMN03283294        0.000000                     0.000000
#          SAMN03283288        0.011865                     0.011865
#
#                            k__Archaea|p__Euryarchaeota|c__Methanobacteria  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                            0.000000
#          SAMN03283266                                            0.000000
#          SAMN03283281                                            0.009764
#          SAMN03283294                                            0.000000
#          SAMN03283288                                            0.011865
#
#                            k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                               0.000000
#          SAMN03283266                                               0.000000
#          SAMN03283281                                               0.009764
#          SAMN03283294                                               0.000000
#          SAMN03283288                                               0.011865
#
#                            k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                               0.000000
#          SAMN03283266                                               0.000000
#          SAMN03283281                                               0.009764
#          SAMN03283294                                               0.000000
#          SAMN03283288                                               0.011865
#
#                            k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanobrevibacter  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                               0.000000
#          SAMN03283266                                               0.000000
#          SAMN03283281                                               0.009764
#          SAMN03283294                                               0.000000
#          SAMN03283288                                               0.011865
#
#                            k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanobrevibacter|s__Methanobrevibacter_smithii  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                               0.000000
#          SAMN03283266                                               0.000000
#          SAMN03283281                                               0.009764
#          SAMN03283294                                               0.000000
#          SAMN03283288                                               0.011865
#
#                            k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanosphaera  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                                    0.0
#          SAMN03283266                                                    0.0
#          SAMN03283281                                                    0.0
#          SAMN03283294                                                    0.0
#          SAMN03283288                                                    0.0
#
#                            k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanosphaera|s__Methanosphaera_stadtmanae  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                                    0.0
#          SAMN03283266                                                    0.0
#          SAMN03283281                                                    0.0
#          SAMN03283294                                                    0.0
#          SAMN03283288                                                    0.0
#
#                            k__Archaea|p__Euryarchaeota|c__Thermoplasmata  ...  \
# Study_ID Sample Accession                                                 ...
# GMHI-10  SAMN03283239                                                0.0  ...
#          SAMN03283266                                                0.0  ...
#          SAMN03283281                                                0.0  ...
#          SAMN03283294                                                0.0  ...
#          SAMN03283288                                                0.0  ...
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Hordeivirus|s__Barley_stripe_mosaic_virus  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                                    0.0
#          SAMN03283266                                                    0.0
#          SAMN03283281                                                    0.0
#          SAMN03283294                                                    0.0
#          SAMN03283288                                                    0.0
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                                    0.0
#          SAMN03283266                                                    0.0
#          SAMN03283281                                                    0.0
#          SAMN03283294                                                    0.0
#          SAMN03283288                                                    0.0
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Cactus_mild_mottle_virus  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                                    0.0
#          SAMN03283266                                                    0.0
#          SAMN03283281                                                    0.0
#          SAMN03283294                                                    0.0
#          SAMN03283288                                                    0.0
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Cucumber_green_mottle_mosaic_virus  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                                    0.0
#          SAMN03283266                                                    0.0
#          SAMN03283281                                                    0.0
#          SAMN03283294                                                    0.0
#          SAMN03283288                                                    0.0
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Paprika_mild_mottle_virus  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                                    0.0
#          SAMN03283266                                                    0.0
#          SAMN03283281                                                    0.0
#          SAMN03283294                                                    0.0
#          SAMN03283288                                                    0.0
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Pepper_mild_mottle_virus  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                                    0.0
#          SAMN03283266                                                    0.0
#          SAMN03283281                                                    0.0
#          SAMN03283294                                                    0.0
#          SAMN03283288                                                    0.0
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Tobacco_mild_green_mosaic_virus  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                                    0.0
#          SAMN03283266                                                    0.0
#          SAMN03283281                                                    0.0
#          SAMN03283294                                                    0.0
#          SAMN03283288                                                    0.0
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Viruses_unclassified|g__Viruses_unclassified|s__Deep_sea_thermophilic_phage_D6E  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                                    0.0
#          SAMN03283266                                                    0.0
#          SAMN03283281                                                    0.0
#          SAMN03283294                                                    0.0
#          SAMN03283288                                                    0.0
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Viruses_unclassified|g__Viruses_unclassified|s__Loktanella_phage_pCB2051_A  \
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                                    0.0
#          SAMN03283266                                                    0.0
#          SAMN03283281                                                    0.0
#          SAMN03283294                                                    0.0
#          SAMN03283288                                                    0.0
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Viruses_unclassified|g__Viruses_unclassified|s__Tetraselmis_viridis_virus_S1
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                                                    0.0
#          SAMN03283266                                                    0.0
#          SAMN03283281                                                    0.0
#          SAMN03283294                                                    0.0
#          SAMN03283288                                                    0.0
#
# [5 rows x 3200 columns]
#                            PHENOTYPE:Healthy_Nonhealthy
# Study_ID Sample Accession
# GMHI-10  SAMN03283239                              True
#          SAMN03283266                              True
#          SAMN03283281                              True
#          SAMN03283294                              True
#          SAMN03283288                              True

# %% [markdown]
# # Train Models!

# %% [markdown]
# ## Train GMHI model on entire dataset

# %%
import numpy as np
from tqdm import tqdm

results = []

X_GMHI = X.copy()
X_GMHI = X_GMHI[list(filter(lambda x : "s__" in x and "virus" not in x, X_GMHI.columns))]

for theta_f in tqdm(np.arange(1, 3.1, 0.1)):
    for theta_d in np.arange(0.05, 0.35, 0.05):
        gmhi = GMHI(use_shannon=True, theta_f=theta_f, theta_d=theta_d)

        gmhi.fit(X_GMHI, y)
        GMHI_scores = pd.DataFrame(gmhi.decision_function(X_GMHI), index=y.index, columns=["GMHI"])
        bal = balanced_accuracy_score(y, GMHI_scores > 0)
        results.append({"f" : theta_f, "d" : theta_d, "bal" : bal})
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 21/21 [00:16<00:00,  1.29it/s]

# %%
sorted(results, key=lambda x : -x['bal'])
# Out:
# [{'f': 2.000000000000001, 'd': 0.1, 'bal': 0.7408457279563423},
#  {'f': 2.000000000000001, 'd': 0.05, 'bal': 0.738593758734208},
#  {'f': 1.8000000000000007, 'd': 0.1, 'bal': 0.7376708902526703},
#  {'f': 1.9000000000000008, 'd': 0.05, 'bal': 0.7376549140235836},
#  {'f': 2.200000000000001, 'd': 0.05, 'bal': 0.7363914695085627},
#  {'f': 1.7000000000000006, 'd': 0.1, 'bal': 0.7350793457451835},
#  {'f': 2.200000000000001, 'd': 0.1, 'bal': 0.7345142804613791},
#  {'f': 2.100000000000001, 'd': 0.1, 'bal': 0.7344998053544886},
#  {'f': 1.8000000000000007, 'd': 0.05, 'bal': 0.7340678395720687},
#  {'f': 2.100000000000001, 'd': 0.05, 'bal': 0.7335824409876698},
#  {'f': 2.300000000000001, 'd': 0.05, 'bal': 0.733255589499979},
#  {'f': 1.9000000000000008, 'd': 0.1, 'bal': 0.7327684396063514},
#  {'f': 2.4000000000000012, 'd': 0.05, 'bal': 0.7319766691299368},
#  {'f': 2.5000000000000013, 'd': 0.05, 'bal': 0.731848573369206},
#  {'f': 2.300000000000001, 'd': 0.1, 'bal': 0.7314138555294265},
#  {'f': 1.7000000000000006, 'd': 0.05, 'bal': 0.7310807851069235},
#  {'f': 2.4000000000000012, 'd': 0.1, 'bal': 0.7301888683354285},
#  {'f': 2.5000000000000013, 'd': 0.1, 'bal': 0.7297179448579202},
#  {'f': 1.6000000000000005, 'd': 0.1, 'bal': 0.7265798489070472},
#  {'f': 1.6000000000000005, 'd': 0.05, 'bal': 0.7250122841833044},
#  {'f': 2.6000000000000014, 'd': 0.05, 'bal': 0.7244154808873549},
#  {'f': 1.5000000000000004, 'd': 0.05, 'bal': 0.723427242108279},
#  {'f': 1.5000000000000004, 'd': 0.1, 'bal': 0.7228167500075413},
#  {'f': 3.0000000000000018, 'd': 0.05, 'bal': 0.7213105525888139},
#  {'f': 2.9000000000000017, 'd': 0.05, 'bal': 0.7211302749612675},
#  {'f': 2.6000000000000014, 'd': 0.1, 'bal': 0.7193629537624341},
#  {'f': 1.4000000000000004, 'd': 0.05, 'bal': 0.718980239084447},
#  {'f': 2.8000000000000016, 'd': 0.05, 'bal': 0.7183359717342979},
#  {'f': 2.000000000000001, 'd': 0.15000000000000002, 'bal': 0.71773198449641},
#  {'f': 2.7000000000000015, 'd': 0.05, 'bal': 0.7174183571804464},
#  {'f': 1.4000000000000004, 'd': 0.1, 'bal': 0.7172501242714733},
#  {'f': 1.8000000000000007,
#   'd': 0.15000000000000002,
#   'bal': 0.7168475733358952},
#  {'f': 1.6000000000000005,
#   'd': 0.15000000000000002,
#   'bal': 0.7166653299530921},
#  {'f': 1.7000000000000006,
#   'd': 0.15000000000000002,
#   'bal': 0.7148170911196898},
#  {'f': 2.100000000000001, 'd': 0.15000000000000002, 'bal': 0.7129716043436471},
#  {'f': 2.7000000000000015, 'd': 0.1, 'bal': 0.7128889353998497},
#  {'f': 2.9000000000000017, 'd': 0.1, 'bal': 0.711572558456915},
#  {'f': 3.0000000000000018, 'd': 0.1, 'bal': 0.711572558456915},
#  {'f': 2.8000000000000016, 'd': 0.1, 'bal': 0.7103812750303191},
#  {'f': 1.5000000000000004,
#   'd': 0.15000000000000002,
#   'bal': 0.7097131684300564},
#  {'f': 1.9000000000000008,
#   'd': 0.15000000000000002,
#   'bal': 0.7094948981145477},
#  {'f': 1.4000000000000004,
#   'd': 0.15000000000000002,
#   'bal': 0.7054803969882055},
#  {'f': 1.6000000000000005, 'd': 0.2, 'bal': 0.7036329087159015},
#  {'f': 2.200000000000001, 'd': 0.15000000000000002, 'bal': 0.7023451960587108},
#  {'f': 2.5000000000000013,
#   'd': 0.15000000000000002,
#   'bal': 0.7010482979633204},
#  {'f': 2.300000000000001, 'd': 0.15000000000000002, 'bal': 0.7007416758842717},
#  {'f': 2.4000000000000012,
#   'd': 0.15000000000000002,
#   'bal': 0.7007416758842717},
#  {'f': 1.0, 'd': 0.25, 'bal': 0.6965002193782867},
#  {'f': 1.1, 'd': 0.25, 'bal': 0.6965002193782867},
#  {'f': 1.2000000000000002, 'd': 0.25, 'bal': 0.6965002193782867},
#  {'f': 1.3000000000000003, 'd': 0.25, 'bal': 0.6965002193782867},
#  {'f': 1.4000000000000004, 'd': 0.25, 'bal': 0.6965002193782867},
#  {'f': 1.7000000000000006, 'd': 0.2, 'bal': 0.6954709499258518},
#  {'f': 1.6000000000000005, 'd': 0.25, 'bal': 0.6947505899767641},
#  {'f': 1.5000000000000004, 'd': 0.25, 'bal': 0.694222766819824},
#  {'f': 1.5000000000000004, 'd': 0.2, 'bal': 0.6929193996025886},
#  {'f': 1.3000000000000003, 'd': 0.05, 'bal': 0.6887615413065225},
#  {'f': 1.4000000000000004, 'd': 0.2, 'bal': 0.6886324447976608},
#  {'f': 2.100000000000001, 'd': 0.2, 'bal': 0.6863791531583538},
#  {'f': 2.000000000000001, 'd': 0.2, 'bal': 0.6850447984900712},
#  {'f': 1.9000000000000008, 'd': 0.2, 'bal': 0.6840692477676527},
#  {'f': 1.9000000000000008, 'd': 0.25, 'bal': 0.6834779843274266},
#  {'f': 2.000000000000001, 'd': 0.25, 'bal': 0.6834779843274266},
#  {'f': 2.100000000000001, 'd': 0.25, 'bal': 0.6834779843274266},
#  {'f': 1.8000000000000007, 'd': 0.2, 'bal': 0.6830579917815705},
#  {'f': 1.3000000000000003, 'd': 0.1, 'bal': 0.6827234917188807},
#  {'f': 1.7000000000000006, 'd': 0.25, 'bal': 0.6825920720447157},
#  {'f': 1.8000000000000007, 'd': 0.25, 'bal': 0.6825920720447157},
#  {'f': 1.3000000000000003,
#   'd': 0.15000000000000002,
#   'bal': 0.6752070154731387},
#  {'f': 1.2000000000000002, 'd': 0.05, 'bal': 0.6675344940010153},
#  {'f': 1.2000000000000002, 'd': 0.1, 'bal': 0.6626140656293483},
#  {'f': 1.0, 'd': 0.2, 'bal': 0.6574209691330677},
#  {'f': 1.1, 'd': 0.2, 'bal': 0.6574209691330677},
#  {'f': 1.2000000000000002, 'd': 0.2, 'bal': 0.6574209691330677},
#  {'f': 1.3000000000000003, 'd': 0.2, 'bal': 0.6574209691330677},
#  {'f': 2.9000000000000017,
#   'd': 0.15000000000000002,
#   'bal': 0.6565119681613412},
#  {'f': 3.0000000000000018,
#   'd': 0.15000000000000002,
#   'bal': 0.6565119681613412},
#  {'f': 2.8000000000000016,
#   'd': 0.15000000000000002,
#   'bal': 0.6546897130383328},
#  {'f': 2.6000000000000014,
#   'd': 0.15000000000000002,
#   'bal': 0.6546894628513001},
#  {'f': 2.7000000000000015,
#   'd': 0.15000000000000002,
#   'bal': 0.6546894628513001},
#  {'f': 1.0, 'd': 0.15000000000000002, 'bal': 0.6496186005909846},
#  {'f': 1.1, 'd': 0.15000000000000002, 'bal': 0.6496186005909846},
#  {'f': 1.2000000000000002,
#   'd': 0.15000000000000002,
#   'bal': 0.6496186005909846},
#  {'f': 1.0, 'd': 0.1, 'bal': 0.6489359474018219},
#  {'f': 1.1, 'd': 0.1, 'bal': 0.6489359474018219},
#  {'f': 2.200000000000001, 'd': 0.2, 'bal': 0.6414982443303687},
#  {'f': 1.1, 'd': 0.05, 'bal': 0.6398179524779024},
#  {'f': 2.300000000000001, 'd': 0.2, 'bal': 0.639443779900031},
#  {'f': 2.4000000000000012, 'd': 0.2, 'bal': 0.639443779900031},
#  {'f': 2.5000000000000013, 'd': 0.2, 'bal': 0.639443779900031},
#  {'f': 2.200000000000001, 'd': 0.25, 'bal': 0.6383623643217852},
#  {'f': 2.300000000000001, 'd': 0.25, 'bal': 0.6370290104016331},
#  {'f': 2.4000000000000012, 'd': 0.25, 'bal': 0.6370290104016331},
#  {'f': 2.5000000000000013, 'd': 0.25, 'bal': 0.6370290104016331},
#  {'f': 1.0, 'd': 0.05, 'bal': 0.6259408283363834},
#  {'f': 1.0, 'd': 0.3, 'bal': 0.5},
#  {'f': 1.1, 'd': 0.3, 'bal': 0.5},
#  {'f': 1.2000000000000002, 'd': 0.3, 'bal': 0.5},
#  {'f': 1.3000000000000003, 'd': 0.3, 'bal': 0.5},
#  {'f': 1.4000000000000004, 'd': 0.3, 'bal': 0.5},
#  {'f': 1.5000000000000004, 'd': 0.3, 'bal': 0.5},
#  {'f': 1.6000000000000005, 'd': 0.3, 'bal': 0.5},
#  {'f': 1.7000000000000006, 'd': 0.3, 'bal': 0.5},
#  {'f': 1.8000000000000007, 'd': 0.3, 'bal': 0.5},
#  {'f': 1.9000000000000008, 'd': 0.3, 'bal': 0.5},
#  {'f': 2.000000000000001, 'd': 0.3, 'bal': 0.5},
#  {'f': 2.100000000000001, 'd': 0.3, 'bal': 0.5},
#  {'f': 2.200000000000001, 'd': 0.3, 'bal': 0.5},
#  {'f': 2.300000000000001, 'd': 0.3, 'bal': 0.5},
#  {'f': 2.4000000000000012, 'd': 0.3, 'bal': 0.5},
#  {'f': 2.5000000000000013, 'd': 0.3, 'bal': 0.5},
#  {'f': 2.6000000000000014, 'd': 0.2, 'bal': 0.5},
#  {'f': 2.6000000000000014, 'd': 0.25, 'bal': 0.5},
#  {'f': 2.6000000000000014, 'd': 0.3, 'bal': 0.5},
#  {'f': 2.7000000000000015, 'd': 0.2, 'bal': 0.5},
#  {'f': 2.7000000000000015, 'd': 0.25, 'bal': 0.5},
#  {'f': 2.7000000000000015, 'd': 0.3, 'bal': 0.5},
#  {'f': 2.8000000000000016, 'd': 0.2, 'bal': 0.5},
#  {'f': 2.8000000000000016, 'd': 0.25, 'bal': 0.5},
#  {'f': 2.8000000000000016, 'd': 0.3, 'bal': 0.5},
#  {'f': 2.9000000000000017, 'd': 0.2, 'bal': 0.5},
#  {'f': 2.9000000000000017, 'd': 0.25, 'bal': 0.5},
#  {'f': 2.9000000000000017, 'd': 0.3, 'bal': 0.5},
#  {'f': 3.0000000000000018, 'd': 0.2, 'bal': 0.5},
#  {'f': 3.0000000000000018, 'd': 0.25, 'bal': 0.5},
#  {'f': 3.0000000000000018, 'd': 0.3, 'bal': 0.5}]

# %%
gmhi = GMHI(use_shannon=True, theta_f=2, theta_d=0.1)
gmhi.fit(X_GMHI, y)

# %%
len(gmhi.health_abundant)
# Out:
# 16

# %%
len(gmhi.health_scarce)
# Out:
# 34

# %%
with open(os.path.join(config.LOG_DIR, "gmhi_health_abundant.txt"), "w") as f:
    for a in gmhi.health_abundant:
        f.write(a + "\n")

# %%
with open(os.path.join(config.LOG_DIR, "gmhi_health_scarce.txt"), "w") as f:
    for s in gmhi.health_scarce:
        f.write(s + "\n")

# %%
# use same parameters as original paper
gmhi = GMHI(use_shannon=True, theta_f=1.4, theta_d=0.1)

# use only non-viral species
X_GMHI = X.copy()
X_GMHI = X_GMHI[list(filter(lambda x : "s__" in x and "virus" not in x, X_GMHI.columns))]

gmhi.fit(X_GMHI, y)
GMHI_scores = pd.DataFrame(gmhi.decision_function(X_GMHI), index=y.index, columns=["GMHI"])
display(GMHI_scores)
print("GMHI balanced_accuracy on training set:", balanced_accuracy_score(y, GMHI_scores > 0))
idx = (abs(GMHI_scores) >= 0.1).values
print("GMHI balanced_accuracy on training set for |GMHI| >= 0.1:", balanced_accuracy_score(y[idx], GMHI_scores[idx] > 0))
idx = (abs(GMHI_scores) >= 1).values
print("GMHI balanced_accuracy on training set for |GMHI| >= 1:", balanced_accuracy_score(y[idx], GMHI_scores[idx] > 0))
# Out:
#                                 GMHI
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239      3.832094
#           SAMN03283266      1.758548
#           SAMN03283281      3.341858
#           SAMN03283294      1.429055
#           SAMN03283288      1.064592
# ...                              ...
# Yang_2020 SRR6456373       -4.472053
#           SRR6456374       -2.158801
#           SRR6456375        0.280615
#           SRR6456376        1.132266
#           SRR6456377       -0.305132
#
# [8069 rows x 1 columns]
# GMHI balanced_accuracy on training set: 0.7172501242714733
# GMHI balanced_accuracy on training set for |GMHI| >= 0.1: 0.7228776593558975
# GMHI balanced_accuracy on training set for |GMHI| >= 1: 0.785641042415692

# %% [markdown]
# ## Train GMHI2 model on entire dataset

# %%
gmhi2 = LogisticRegression(random_state=42, penalty="l1", solver="liblinear", C=config.REGULARIZATION, class_weight="balanced")

X_GMHI2 = X > config.PRESENCE_CUTOFF
X_GMHI2
# Out:
#                             k__Archaea  k__Archaea|p__Euryarchaeota  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239           False                        False
#           SAMN03283266           False                        False
#           SAMN03283281            True                         True
#           SAMN03283294           False                        False
#           SAMN03283288            True                         True
# ...                                ...                          ...
# Yang_2020 SRR6456373             False                        False
#           SRR6456374             False                        False
#           SRR6456375             False                        False
#           SRR6456376              True                         True
#           SRR6456377             False                        False
#
#                             k__Archaea|p__Euryarchaeota|c__Methanobacteria  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                               False
#           SAMN03283266                                               False
#           SAMN03283281                                                True
#           SAMN03283294                                               False
#           SAMN03283288                                                True
# ...                                                                    ...
# Yang_2020 SRR6456373                                                 False
#           SRR6456374                                                 False
#           SRR6456375                                                 False
#           SRR6456376                                                  True
#           SRR6456377                                                 False
#
#                             k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                   True
#           SAMN03283294                                                  False
#           SAMN03283288                                                   True
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                     True
#           SRR6456377                                                    False
#
#                             k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                   True
#           SAMN03283294                                                  False
#           SAMN03283288                                                   True
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                     True
#           SRR6456377                                                    False
#
#                             k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanobrevibacter  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                   True
#           SAMN03283294                                                  False
#           SAMN03283288                                                   True
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                     True
#           SRR6456377                                                    False
#
#                             k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanobrevibacter|s__Methanobrevibacter_smithii  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                   True
#           SAMN03283294                                                  False
#           SAMN03283288                                                   True
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                     True
#           SRR6456377                                                    False
#
#                             k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanosphaera  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                  False
#           SAMN03283294                                                  False
#           SAMN03283288                                                  False
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                    False
#           SRR6456377                                                    False
#
#                             k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales|f__Methanobacteriaceae|g__Methanosphaera|s__Methanosphaera_stadtmanae  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                  False
#           SAMN03283294                                                  False
#           SAMN03283288                                                  False
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                    False
#           SRR6456377                                                    False
#
#                             k__Archaea|p__Euryarchaeota|c__Thermoplasmata  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                              False
#           SAMN03283266                                              False
#           SAMN03283281                                              False
#           SAMN03283294                                              False
#           SAMN03283288                                              False
# ...                                                                   ...
# Yang_2020 SRR6456373                                                False
#           SRR6456374                                                False
#           SRR6456375                                                False
#           SRR6456376                                                False
#           SRR6456377                                                False
#
#                             ...  \
# Study_ID  Sample Accession  ...
# GMHI-10   SAMN03283239      ...
#           SAMN03283266      ...
#           SAMN03283281      ...
#           SAMN03283294      ...
#           SAMN03283288      ...
# ...                         ...
# Yang_2020 SRR6456373        ...
#           SRR6456374        ...
#           SRR6456375        ...
#           SRR6456376        ...
#           SRR6456377        ...
#
#                             k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Hordeivirus|s__Barley_stripe_mosaic_virus  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                  False
#           SAMN03283294                                                  False
#           SAMN03283288                                                  False
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                    False
#           SRR6456377                                                    False
#
#                             k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                  False
#           SAMN03283294                                                  False
#           SAMN03283288                                                  False
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                    False
#           SRR6456377                                                    False
#
#                             k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Cactus_mild_mottle_virus  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                  False
#           SAMN03283294                                                  False
#           SAMN03283288                                                  False
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                    False
#           SRR6456377                                                    False
#
#                             k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Cucumber_green_mottle_mosaic_virus  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                  False
#           SAMN03283294                                                  False
#           SAMN03283288                                                  False
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                    False
#           SRR6456377                                                    False
#
#                             k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Paprika_mild_mottle_virus  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                  False
#           SAMN03283294                                                  False
#           SAMN03283288                                                  False
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                    False
#           SRR6456377                                                    False
#
#                             k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Pepper_mild_mottle_virus  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                  False
#           SAMN03283294                                                  False
#           SAMN03283288                                                  False
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                    False
#           SRR6456377                                                    False
#
#                             k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Tobacco_mild_green_mosaic_virus  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                  False
#           SAMN03283294                                                  False
#           SAMN03283288                                                  False
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                    False
#           SRR6456377                                                    False
#
#                             k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Viruses_unclassified|g__Viruses_unclassified|s__Deep_sea_thermophilic_phage_D6E  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                  False
#           SAMN03283294                                                  False
#           SAMN03283288                                                  False
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                    False
#           SRR6456377                                                    False
#
#                             k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Viruses_unclassified|g__Viruses_unclassified|s__Loktanella_phage_pCB2051_A  \
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                  False
#           SAMN03283294                                                  False
#           SAMN03283288                                                  False
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                    False
#           SRR6456377                                                    False
#
#                             k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Viruses_unclassified|g__Viruses_unclassified|s__Tetraselmis_viridis_virus_S1
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239                                                  False
#           SAMN03283266                                                  False
#           SAMN03283281                                                  False
#           SAMN03283294                                                  False
#           SAMN03283288                                                  False
# ...                                                                       ...
# Yang_2020 SRR6456373                                                    False
#           SRR6456374                                                    False
#           SRR6456375                                                    False
#           SRR6456376                                                    False
#           SRR6456377                                                    False
#
# [8069 rows x 3200 columns]

# %%
gmhi2.fit(X_GMHI2, y.values.flatten())
GMHI2_scores = pd.DataFrame(gmhi2.decision_function(X_GMHI2), index=y.index, columns=["GMHI2"])
display(GMHI2_scores)
print("GMHI2 balanced_accuracy on training set:", balanced_accuracy_score(y, GMHI2_scores > 0))
idx = (abs(GMHI2_scores) >= 0.5).values
print("GMHI2 balanced_accuracy on training set |GMHI2| >= 0.5:", balanced_accuracy_score(y[idx], GMHI2_scores[idx] > 0))
idx = (abs(GMHI2_scores) >= 1).values
print("GMHI2 balanced_accuracy on training set |GMHI2| >= 1:", balanced_accuracy_score(y[idx], GMHI2_scores[idx] > 0))
# Out:
#                                GMHI2
# Study_ID  Sample Accession
# GMHI-10   SAMN03283239      1.835237
#           SAMN03283266      0.103722
#           SAMN03283281      1.116329
#           SAMN03283294      1.758818
#           SAMN03283288      1.675791
# ...                              ...
# Yang_2020 SRR6456373       -1.029233
#           SRR6456374       -0.941967
#           SRR6456375       -0.030621
#           SRR6456376        0.973798
#           SRR6456377       -0.066339
#
# [8069 rows x 1 columns]
# GMHI2 balanced_accuracy on training set: 0.7988526637127441
# GMHI2 balanced_accuracy on training set |GMHI2| >= 0.5: 0.8575150415882389
# GMHI2 balanced_accuracy on training set |GMHI2| >= 1: 0.9098325472786429

# %%
display(confusion(GMHI2_scores, y, 0))
display(confusion(GMHI2_scores, y, 0.1))
display(confusion(GMHI2_scores, y, 0.5))
display(confusion(GMHI2_scores, y, 1))
# Out:
#                    Predicted Healthy  Predicted Nonhealthy  Accuracy
# Actual Nonhealthy              489.0                2033.0  0.806106
# Actual healthy                4391.0                1156.0  0.791599
#                    Predicted Healthy  Predicted Nonhealthy  Accuracy
# Actual Nonhealthy              434.0                1976.0  0.819917
# Actual healthy                4268.0                1041.0  0.803918
#                    Predicted Healthy  Predicted Nonhealthy  Accuracy
# Actual Nonhealthy              264.0                1678.0  0.864058
# Actual healthy                3763.0                 659.0  0.850972
#                    Predicted Healthy  Predicted Nonhealthy  Accuracy
# Actual Nonhealthy              115.0                1263.0  0.916546
# Actual healthy                3011.0                 323.0  0.903119

# %% [markdown]
# # Export stuff

# %% [markdown]
# ## Export GMHI scores and serialize model

# %%
GMHI_scores.to_csv(os.path.join(config.LOG_DIR, "GMHI_scores_training_set.csv"))
dump(gmhi, os.path.join(config.MODEL_DIR, 'gmhi_model.joblib'))
# Out:
# ['../output/models/gmhi_model.joblib']

# %% [markdown]
# ## Export GMHI2 scores and serialize model

# %%
GMHI2_scores.to_csv(os.path.join(config.LOG_DIR, "GMHI2_scores_training_set.csv"))
dump(gmhi2, os.path.join(config.MODEL_DIR, 'gmhi2_model.joblib'))
# Out:
# ['../output/models/gmhi2_model.joblib']
