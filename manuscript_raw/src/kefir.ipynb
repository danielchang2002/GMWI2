# %%
import pandas as pd
import config
import os
from joblib import load
import numpy as np

# %%
! ls ../data/raw/kefir_metaphlan3_results/
# Out:
# Subj001_time1_S1_metaphlan3.txt
# Subj001_time2_S2_metaphlan3.txt
# Subj003_time1_S3_metaphlan3.txt
# Subj004_time1_S4_metaphlan3.txt
# Subj007_time1_S5_metaphlan3.txt
# Subj008_time1_S6_metaphlan3.txt
# Subj008_time2_S7_metaphlan3.txt
# Subj011_time1_S8_metaphlan3.txt
# Subj011_time2_S9_metaphlan3.txt
# Subj013_time1_S10_metaphlan3.txt
# Subj014_time1_S11_metaphlan3.txt
# Subj015_time2_S12_metaphlan3.txt
# Subj016_time1_S13_metaphlan3.txt
# Subj016_time2_S14_metaphlan3.txt
# Subj017_time1_ReExtract_S44_metaphlan3.txt
# Subj020_time1_S15_metaphlan3.txt
# Subj021_time1_S16_metaphlan3.txt
# Subj021_time2_S17_metaphlan3.txt
# Subj030_time1_S18_metaphlan3.txt
# Subj030_time2_S19_metaphlan3.txt
# Subj030_time3_S20_metaphlan3.txt
# Subj031_time1_S21_metaphlan3.txt
# Subj032_time1_S22_metaphlan3.txt
# Subj032_time2_S23_metaphlan3.txt
# Subj034_time1_S24_metaphlan3.txt
# Subj034_time2_S25_metaphlan3.txt
# Subj035_time1_S26_metaphlan3.txt
# Subj039_time1_S27_metaphlan3.txt
# Subj039_time2_S28_metaphlan3.txt
# Subj040_time1_S29_metaphlan3.txt
# Subj041_time1_S30_metaphlan3.txt
# Subj042_time1_S31_metaphlan3.txt
# Subj043_time1_S32_metaphlan3.txt
# Subj043_time2_S33_metaphlan3.txt
# Subj044_time1_S34_metaphlan3.txt
# Subj045_time1_S35_metaphlan3.txt
# Subj049_time1_S36_metaphlan3.txt
# Subj052_time1_S37_metaphlan3.txt
# Subj052_time2_S38_metaphlan3.txt
# Subj053_time1_S39_metaphlan3.txt
# Subj053_time2_S40_metaphlan3_new.txt
# Subj054_time1_S41_metaphlan3_new.txt
# Subj054_time2_S42_metaphlan3_new.txt
# Subj054_time3_S43_metaphlan3_new.txt
# all_metaphlan3.txt

# %%
def compute_GMWI2(file):
    df = pd.read_csv(file, sep="\t", skiprows=3, usecols=[0, 2], index_col=0).T

    # load model
    gmwi2 = load(os.path.join(config.MODEL_DIR, "GMHI2_model.joblib"))

    # add dummy columns
    dummy_cols = list(set(gmwi2.feature_names_in_) - set(df.columns))
    dummy_df = pd.DataFrame(np.zeros((1, len(dummy_cols))), columns=dummy_cols, index=["relative_abundance"])
    df = pd.concat([dummy_df, df], axis=1)
    df = df.copy()[["UNKNOWN"] + list(gmwi2.feature_names_in_)]

    # normalize relative abundances
    df = df.divide((100 - df["UNKNOWN"]), axis="rows")
    df = df.drop(labels=["UNKNOWN"], axis=1)

    # compute gmwi2
    presence_cutoff = 0.00001
    score = gmwi2.decision_function(df > presence_cutoff)[0]
    return score

# %%
kefir_dir = "../data/raw/kefir_metaphlan3_results/"
gmwi2 = {}

for f in os.listdir(kefir_dir):
    if "all" in f: continue
    score = compute_GMWI2(os.path.join(kefir_dir, f))
    gmwi2[f] = score

# %%
pd.DataFrame(gmwi2, index=["GMWI2"]).T.sort_index()
# Out:
#                                                GMWI2
# Subj001_time1_S1_metaphlan3.txt            -0.574863
# Subj001_time2_S2_metaphlan3.txt             0.176184
# Subj003_time1_S3_metaphlan3.txt            -0.059041
# Subj004_time1_S4_metaphlan3.txt             0.219228
# Subj007_time1_S5_metaphlan3.txt            -1.794307
# Subj008_time1_S6_metaphlan3.txt            -1.168975
# Subj008_time2_S7_metaphlan3.txt            -0.804171
# Subj011_time1_S8_metaphlan3.txt            -1.200323
# Subj011_time2_S9_metaphlan3.txt             0.146706
# Subj013_time1_S10_metaphlan3.txt           -1.005974
# Subj014_time1_S11_metaphlan3.txt           -1.315352
# Subj015_time2_S12_metaphlan3.txt            0.067174
# Subj016_time1_S13_metaphlan3.txt           -1.113159
# Subj016_time2_S14_metaphlan3.txt            0.171534
# Subj017_time1_ReExtract_S44_metaphlan3.txt -1.262019
# Subj020_time1_S15_metaphlan3.txt            0.333846
# Subj021_time1_S16_metaphlan3.txt            0.481311
# Subj021_time2_S17_metaphlan3.txt           -0.119318
# Subj030_time1_S18_metaphlan3.txt           -0.550104
# Subj030_time2_S19_metaphlan3.txt           -1.021217
# Subj030_time3_S20_metaphlan3.txt           -0.359398
# Subj031_time1_S21_metaphlan3.txt           -2.434466
# Subj032_time1_S22_metaphlan3.txt            0.046698
# Subj032_time2_S23_metaphlan3.txt            0.046698
# Subj034_time1_S24_metaphlan3.txt           -1.782764
# Subj034_time2_S25_metaphlan3.txt           -0.360738
# Subj035_time1_S26_metaphlan3.txt           -0.337472
# Subj039_time1_S27_metaphlan3.txt            0.046698
# Subj039_time2_S28_metaphlan3.txt            0.176184
# Subj040_time1_S29_metaphlan3.txt           -0.812810
# Subj041_time1_S30_metaphlan3.txt           -0.966143
# Subj042_time1_S31_metaphlan3.txt           -1.807530
# Subj043_time1_S32_metaphlan3.txt            0.005742
# Subj043_time2_S33_metaphlan3.txt           -0.128230
# Subj044_time1_S34_metaphlan3.txt           -1.445574
# Subj045_time1_S35_metaphlan3.txt           -1.039734
# Subj049_time1_S36_metaphlan3.txt           -0.458505
# Subj052_time1_S37_metaphlan3.txt           -1.041041
# Subj052_time2_S38_metaphlan3.txt           -0.636586
# Subj053_time1_S39_metaphlan3.txt           -1.564757
# Subj053_time2_S40_metaphlan3_new.txt        0.187769
# Subj054_time1_S41_metaphlan3_new.txt       -1.157818
# Subj054_time2_S42_metaphlan3_new.txt       -0.750038
# Subj054_time3_S43_metaphlan3_new.txt       -0.881904

# %%
def compute_GMWI(file):
    df = pd.read_csv(file, sep="\t", skiprows=3, usecols=[0, 2], index_col=0).T

    # load model
    gmwi = load(os.path.join(config.MODEL_DIR, "GMHI_model.joblib"))

    # add dummy columns
    dummy_cols = list(set(gmwi.features) - set(df.columns))
    
    dummy_df = pd.DataFrame(np.zeros((1, len(dummy_cols))), columns=dummy_cols, index=["relative_abundance"])
    df = pd.concat([dummy_df, df], axis=1)
    df = df.copy()[["UNKNOWN"] + list(gmwi.features)]

    # normalize relative abundances
    df = df.divide((100 - df["UNKNOWN"]), axis="rows")
    df = df.drop(labels=["UNKNOWN"], axis=1)

    # compute gmwi
    score = gmwi.decision_function(df)[0]
    return score

# %%
kefir_dir = "../data/raw/kefir_metaphlan3_results/"
gmwi = {}

for f in os.listdir(kefir_dir):
    if "all" in f: continue
    score = compute_GMWI(os.path.join(kefir_dir, f))
    gmwi[f] = score

# %%
results = pd.DataFrame([gmwi2, gmwi], index=["GMWI2", "GMWI"]).T.sort_index()
results
# Out:
#                                                GMWI2      GMWI
# Subj001_time1_S1_metaphlan3.txt            -0.574863 -0.184521
# Subj001_time2_S2_metaphlan3.txt             0.176184  1.512431
# Subj003_time1_S3_metaphlan3.txt            -0.059041  0.355143
# Subj004_time1_S4_metaphlan3.txt             0.219228 -1.004163
# Subj007_time1_S5_metaphlan3.txt            -1.794307 -0.884695
# Subj008_time1_S6_metaphlan3.txt            -1.168975 -0.334715
# Subj008_time2_S7_metaphlan3.txt            -0.804171  0.141104
# Subj011_time1_S8_metaphlan3.txt            -1.200323 -3.858764
# Subj011_time2_S9_metaphlan3.txt             0.146706  2.706158
# Subj013_time1_S10_metaphlan3.txt           -1.005974 -1.255278
# Subj014_time1_S11_metaphlan3.txt           -1.315352 -2.781178
# Subj015_time2_S12_metaphlan3.txt            0.067174  0.300616
# Subj016_time1_S13_metaphlan3.txt           -1.113159 -0.294896
# Subj016_time2_S14_metaphlan3.txt            0.171534  1.581527
# Subj017_time1_ReExtract_S44_metaphlan3.txt -1.262019 -0.521711
# Subj020_time1_S15_metaphlan3.txt            0.333846  2.264604
# Subj021_time1_S16_metaphlan3.txt            0.481311  1.399750
# Subj021_time2_S17_metaphlan3.txt           -0.119318  1.143383
# Subj030_time1_S18_metaphlan3.txt           -0.550104 -0.419744
# Subj030_time2_S19_metaphlan3.txt           -1.021217 -0.794798
# Subj030_time3_S20_metaphlan3.txt           -0.359398  1.281168
# Subj031_time1_S21_metaphlan3.txt           -2.434466 -0.874787
# Subj032_time1_S22_metaphlan3.txt            0.046698  3.003299
# Subj032_time2_S23_metaphlan3.txt            0.046698  2.840076
# Subj034_time1_S24_metaphlan3.txt           -1.782764 -1.566969
# Subj034_time2_S25_metaphlan3.txt           -0.360738  0.238130
# Subj035_time1_S26_metaphlan3.txt           -0.337472 -0.627639
# Subj039_time1_S27_metaphlan3.txt            0.046698  1.789347
# Subj039_time2_S28_metaphlan3.txt            0.176184  2.990646
# Subj040_time1_S29_metaphlan3.txt           -0.812810  0.389446
# Subj041_time1_S30_metaphlan3.txt           -0.966143 -2.872015
# Subj042_time1_S31_metaphlan3.txt           -1.807530 -0.618779
# Subj043_time1_S32_metaphlan3.txt            0.005742  0.952922
# Subj043_time2_S33_metaphlan3.txt           -0.128230  2.426758
# Subj044_time1_S34_metaphlan3.txt           -1.445574 -0.863294
# Subj045_time1_S35_metaphlan3.txt           -1.039734 -0.409739
# Subj049_time1_S36_metaphlan3.txt           -0.458505 -0.772176
# Subj052_time1_S37_metaphlan3.txt           -1.041041 -0.769722
# Subj052_time2_S38_metaphlan3.txt           -0.636586  0.163409
# Subj053_time1_S39_metaphlan3.txt           -1.564757 -0.644275
# Subj053_time2_S40_metaphlan3_new.txt        0.187769  2.788970
# Subj054_time1_S41_metaphlan3_new.txt       -1.157818 -0.350138
# Subj054_time2_S42_metaphlan3_new.txt       -0.750038 -0.412726
# Subj054_time3_S43_metaphlan3_new.txt       -0.881904 -0.530540

# %%
results.to_csv(os.path.join(config.LOG_DIR, "kefir_results.csv"))

# %%
time = [t.split("_")[1] for t in results.index]
subject = [t.split("_")[0] for t in results.index]

results["time"] = time
results["subject"] = subject

# %%
results = results[results["time"] != "time3"]
results
# Out:
#                                                GMWI2      GMWI   time  subject
# Subj001_time1_S1_metaphlan3.txt            -0.574863 -0.184521  time1  Subj001
# Subj001_time2_S2_metaphlan3.txt             0.176184  1.512431  time2  Subj001
# Subj003_time1_S3_metaphlan3.txt            -0.059041  0.355143  time1  Subj003
# Subj004_time1_S4_metaphlan3.txt             0.219228 -1.004163  time1  Subj004
# Subj007_time1_S5_metaphlan3.txt            -1.794307 -0.884695  time1  Subj007
# Subj008_time1_S6_metaphlan3.txt            -1.168975 -0.334715  time1  Subj008
# Subj008_time2_S7_metaphlan3.txt            -0.804171  0.141104  time2  Subj008
# Subj011_time1_S8_metaphlan3.txt            -1.200323 -3.858764  time1  Subj011
# Subj011_time2_S9_metaphlan3.txt             0.146706  2.706158  time2  Subj011
# Subj013_time1_S10_metaphlan3.txt           -1.005974 -1.255278  time1  Subj013
# Subj014_time1_S11_metaphlan3.txt           -1.315352 -2.781178  time1  Subj014
# Subj015_time2_S12_metaphlan3.txt            0.067174  0.300616  time2  Subj015
# Subj016_time1_S13_metaphlan3.txt           -1.113159 -0.294896  time1  Subj016
# Subj016_time2_S14_metaphlan3.txt            0.171534  1.581527  time2  Subj016
# Subj017_time1_ReExtract_S44_metaphlan3.txt -1.262019 -0.521711  time1  Subj017
# Subj020_time1_S15_metaphlan3.txt            0.333846  2.264604  time1  Subj020
# Subj021_time1_S16_metaphlan3.txt            0.481311  1.399750  time1  Subj021
# Subj021_time2_S17_metaphlan3.txt           -0.119318  1.143383  time2  Subj021
# Subj030_time1_S18_metaphlan3.txt           -0.550104 -0.419744  time1  Subj030
# Subj030_time2_S19_metaphlan3.txt           -1.021217 -0.794798  time2  Subj030
# Subj031_time1_S21_metaphlan3.txt           -2.434466 -0.874787  time1  Subj031
# Subj032_time1_S22_metaphlan3.txt            0.046698  3.003299  time1  Subj032
# Subj032_time2_S23_metaphlan3.txt            0.046698  2.840076  time2  Subj032
# Subj034_time1_S24_metaphlan3.txt           -1.782764 -1.566969  time1  Subj034
# Subj034_time2_S25_metaphlan3.txt           -0.360738  0.238130  time2  Subj034
# Subj035_time1_S26_metaphlan3.txt           -0.337472 -0.627639  time1  Subj035
# Subj039_time1_S27_metaphlan3.txt            0.046698  1.789347  time1  Subj039
# Subj039_time2_S28_metaphlan3.txt            0.176184  2.990646  time2  Subj039
# Subj040_time1_S29_metaphlan3.txt           -0.812810  0.389446  time1  Subj040
# Subj041_time1_S30_metaphlan3.txt           -0.966143 -2.872015  time1  Subj041
# Subj042_time1_S31_metaphlan3.txt           -1.807530 -0.618779  time1  Subj042
# Subj043_time1_S32_metaphlan3.txt            0.005742  0.952922  time1  Subj043
# Subj043_time2_S33_metaphlan3.txt           -0.128230  2.426758  time2  Subj043
# Subj044_time1_S34_metaphlan3.txt           -1.445574 -0.863294  time1  Subj044
# Subj045_time1_S35_metaphlan3.txt           -1.039734 -0.409739  time1  Subj045
# Subj049_time1_S36_metaphlan3.txt           -0.458505 -0.772176  time1  Subj049
# Subj052_time1_S37_metaphlan3.txt           -1.041041 -0.769722  time1  Subj052
# Subj052_time2_S38_metaphlan3.txt           -0.636586  0.163409  time2  Subj052
# Subj053_time1_S39_metaphlan3.txt           -1.564757 -0.644275  time1  Subj053
# Subj053_time2_S40_metaphlan3_new.txt        0.187769  2.788970  time2  Subj053
# Subj054_time1_S41_metaphlan3_new.txt       -1.157818 -0.350138  time1  Subj054
# Subj054_time2_S42_metaphlan3_new.txt       -0.750038 -0.412726  time2  Subj054

# %%
from scipy.stats import wilcoxon

# %%
count = results.groupby("subject").count()
in_both = count[count["time"] == 2].index

# %%
wilc_df = results[results["subject"].isin(in_both)]

# %%
import matplotlib.pyplot as plt

wilcoxon(wilc_df[wilc_df["time"] == "time1"]["GMWI2"], wilc_df[wilc_df["time"] == "time2"]["GMWI2"], alternative='less')
# Out:
# WilcoxonResult(statistic=15.0, pvalue=0.029869507727696205)

# %%
wilcoxon(wilc_df[wilc_df["time"] == "time1"]["GMWI"], wilc_df[wilc_df["time"] == "time2"]["GMWI"], alternative='less')
# Out:
# WilcoxonResult(statistic=10.0, pvalue=0.0052490234375)
