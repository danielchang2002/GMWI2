# %%
import pandas as pd
import config
import os
from joblib import load
import numpy as np

# %%
! ls ../data/raw/kefir_metaphlan3_results/gmwi2_conda_result
# Out:
# Subj001_time1_S1_GMWI2.txt
# Subj001_time1_S1_GMWI2_taxa.txt
# Subj001_time1_S1_metaphlan.txt
# Subj001_time2_S2_GMWI2.txt
# Subj001_time2_S2_GMWI2_taxa.txt
# Subj001_time2_S2_metaphlan.txt
# Subj003_time1_S3_GMWI2.txt
# Subj003_time1_S3_GMWI2_taxa.txt
# Subj003_time1_S3_metaphlan.txt
# Subj004_time1_S4_GMWI2.txt
# Subj004_time1_S4_GMWI2_taxa.txt
# Subj004_time1_S4_metaphlan.txt
# Subj007_time1_S5_GMWI2.txt
# Subj007_time1_S5_GMWI2_taxa.txt
# Subj007_time1_S5_metaphlan.txt
# Subj008_time1_S6_GMWI2.txt
# Subj008_time1_S6_GMWI2_taxa.txt
# Subj008_time1_S6_metaphlan.txt
# Subj008_time2_S7_GMWI2.txt
# Subj008_time2_S7_GMWI2_taxa.txt
# Subj008_time2_S7_metaphlan.txt
# Subj011_time1_S8_GMWI2.txt
# Subj011_time1_S8_GMWI2_taxa.txt
# Subj011_time1_S8_metaphlan.txt
# Subj011_time2_S9_GMWI2.txt
# Subj011_time2_S9_GMWI2_taxa.txt
# Subj011_time2_S9_metaphlan.txt
# Subj013_time1_S10_GMWI2.txt
# Subj013_time1_S10_GMWI2_taxa.txt
# Subj013_time1_S10_metaphlan.txt
# Subj014_time1_S11_GMWI2.txt
# Subj014_time1_S11_GMWI2_taxa.txt
# Subj014_time1_S11_metaphlan.txt
# Subj015_time2_S12_GMWI2.txt
# Subj015_time2_S12_GMWI2_taxa.txt
# Subj015_time2_S12_metaphlan.txt
# Subj016_time1_S13_GMWI2.txt
# Subj016_time1_S13_GMWI2_taxa.txt
# Subj016_time1_S13_metaphlan.txt
# Subj016_time2_S14_GMWI2.txt
# Subj016_time2_S14_GMWI2_taxa.txt
# Subj016_time2_S14_metaphlan.txt
# Subj017_time1_ReExtract_S44_GMWI2.txt
# Subj017_time1_ReExtract_S44_GMWI2_taxa.txt
# Subj017_time1_ReExtract_S44_metaphlan.txt
# Subj020_time1_S15_GMWI2.txt
# Subj020_time1_S15_GMWI2_taxa.txt
# Subj020_time1_S15_metaphlan.txt
# Subj021_time1_S16_GMWI2.txt
# Subj021_time1_S16_GMWI2_taxa.txt
# Subj021_time1_S16_metaphlan.txt
# Subj021_time2_S17_GMWI2.txt
# Subj021_time2_S17_GMWI2_taxa.txt
# Subj021_time2_S17_metaphlan.txt
# Subj030_time1_S18_GMWI2.txt
# Subj030_time1_S18_GMWI2_taxa.txt
# Subj030_time1_S18_metaphlan.txt
# Subj030_time2_S19_GMWI2.txt
# Subj030_time2_S19_GMWI2_taxa.txt
# Subj030_time2_S19_metaphlan.txt
# Subj030_time3_S20_GMWI2.txt
# Subj030_time3_S20_GMWI2_taxa.txt
# Subj030_time3_S20_metaphlan.txt
# Subj031_time1_S21_GMWI2.txt
# Subj031_time1_S21_GMWI2_taxa.txt
# Subj031_time1_S21_metaphlan.txt
# Subj032_time1_S22_GMWI2.txt
# Subj032_time1_S22_GMWI2_taxa.txt
# Subj032_time1_S22_metaphlan.txt
# Subj032_time2_S23_GMWI2.txt
# Subj032_time2_S23_GMWI2_taxa.txt
# Subj032_time2_S23_metaphlan.txt
# Subj034_time1_S24_GMWI2.txt
# Subj034_time1_S24_GMWI2_taxa.txt
# Subj034_time1_S24_metaphlan.txt
# Subj034_time2_S25_GMWI2.txt
# Subj034_time2_S25_GMWI2_taxa.txt
# Subj034_time2_S25_metaphlan.txt
# Subj035_time1_S26_GMWI2.txt
# Subj035_time1_S26_GMWI2_taxa.txt
# Subj035_time1_S26_metaphlan.txt
# Subj039_time1_S27_GMWI2.txt
# Subj039_time1_S27_GMWI2_taxa.txt
# Subj039_time1_S27_metaphlan.txt
# Subj039_time2_S28_GMWI2.txt
# Subj039_time2_S28_GMWI2_taxa.txt
# Subj039_time2_S28_metaphlan.txt
# Subj040_time1_S29_GMWI2.txt
# Subj040_time1_S29_GMWI2_taxa.txt
# Subj040_time1_S29_metaphlan.txt
# Subj041_time1_S30_GMWI2.txt
# Subj041_time1_S30_GMWI2_taxa.txt
# Subj041_time1_S30_metaphlan.txt
# Subj042_time1_S31_GMWI2.txt
# Subj042_time1_S31_GMWI2_taxa.txt
# Subj042_time1_S31_metaphlan.txt
# Subj043_time1_S32_GMWI2.txt
# Subj043_time1_S32_GMWI2_taxa.txt
# Subj043_time1_S32_metaphlan.txt
# Subj043_time2_S33_GMWI2.txt
# Subj043_time2_S33_GMWI2_taxa.txt
# Subj043_time2_S33_metaphlan.txt
# Subj044_time1_S34_GMWI2.txt
# Subj044_time1_S34_GMWI2_taxa.txt
# Subj044_time1_S34_metaphlan.txt
# Subj045_time1_S35_GMWI2.txt
# Subj045_time1_S35_GMWI2_taxa.txt
# Subj045_time1_S35_metaphlan.txt
# Subj049_time1_S36_GMWI2.txt
# Subj049_time1_S36_GMWI2_taxa.txt
# Subj049_time1_S36_metaphlan.txt
# Subj052_time1_S37_GMWI2.txt
# Subj052_time1_S37_GMWI2_taxa.txt
# Subj052_time1_S37_metaphlan.txt
# Subj052_time2_S38_GMWI2.txt
# Subj052_time2_S38_GMWI2_taxa.txt
# Subj052_time2_S38_metaphlan.txt
# Subj053_time1_S39_GMWI2.txt
# Subj053_time1_S39_GMWI2_taxa.txt
# Subj053_time1_S39_metaphlan.txt
# Subj053_time2_S40_GMWI2.txt
# Subj053_time2_S40_GMWI2_taxa.txt
# Subj053_time2_S40_metaphlan.txt
# Subj054_time1_S41_GMWI2.txt
# Subj054_time1_S41_GMWI2_taxa.txt
# Subj054_time1_S41_metaphlan.txt
# Subj054_time2_S42_GMWI2.txt
# Subj054_time2_S42_GMWI2_taxa.txt
# Subj054_time2_S42_metaphlan.txt
# Subj054_time3_S43_GMWI2.txt
# Subj054_time3_S43_GMWI2_taxa.txt
# Subj054_time3_S43_metaphlan.txt

# %%
def compute_GMWI2(file):
    df = pd.read_csv(file, sep="\t", skiprows=3, usecols=[0, 2], index_col=0).T

    # load model
    gmwi2 = load(os.path.join(config.MODEL_DIR, "GMHI2_model.joblib"))

    # add dummy columns
    dummy_cols = list(set(gmwi2.feature_names_in_) - set(df.columns))
    dummy_df = pd.DataFrame(np.zeros((1, len(dummy_cols))), columns=dummy_cols, index=["relative_abundance"])
    df = pd.concat([dummy_df, df], axis=1)
    df = df.copy()[["UNKNOWN"] + list(gmwi2.feature_names_in_)]

    # normalize relative abundances
    df = df.divide((100 - df["UNKNOWN"]), axis="rows")
    df = df.drop(labels=["UNKNOWN"], axis=1)

    # compute gmwi2
    presence_cutoff = 0.00001
    score = gmwi2.decision_function(df > presence_cutoff)[0]
    return score

# %%
kefir_dir = "../data/raw/kefir_metaphlan3_results/"
gmwi2 = {}

for f in os.listdir(kefir_dir):
    if "all" in f: continue
    score = compute_GMWI2(os.path.join(kefir_dir, f))
    gmwi2[f] = score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 6
#       4 for f in os.listdir(kefir_dir):
#       5     if "all" in f: continue
# ----> 6     score = compute_GMWI2(os.path.join(kefir_dir, f))
#       7     gmwi2[f] = score
#
# Cell In[124], line 2, in compute_GMWI2(file)
#       1 def compute_GMWI2(file):
# ----> 2     df = pd.read_csv(file, sep="\t", skiprows=3, usecols=[0, 2], index_col=0).T
#       4     # load model
#       5     gmwi2 = load(os.path.join(config.MODEL_DIR, "GMHI2_model.joblib"))
#
# File ~/opt/anaconda3/envs/gmwi2_analysis/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/gmwi2_analysis/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/gmwi2_analysis/lib/python3.11/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/gmwi2_analysis/lib/python3.11/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/opt/anaconda3/envs/gmwi2_analysis/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/envs/gmwi2_analysis/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/opt/anaconda3/envs/gmwi2_analysis/lib/python3.11/site-packages/pandas/io/common.py:790, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     788             raise ValueError(f"Zero files found in ZIP file {path_or_buf}")
#     789         else:
# --> 790             raise ValueError(
#     791                 "Multiple files found in ZIP file. "
#     792                 f"Only one file per ZIP: {zip_names}"
#     793             )
#     795 # TAR Encoding
#     796 elif compression == "tar":
#
# ValueError: Multiple files found in ZIP file. Only one file per ZIP: ['gmwi2_conda_result/', 'gmwi2_conda_result/Subj017_time1_ReExtract_S44_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj043_time1_S32_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj004_time1_S4_GMWI2.txt', 'gmwi2_conda_result/Subj043_time1_S32_metaphlan.txt', 'gmwi2_conda_result/Subj054_time1_S41_GMWI2.txt', 'gmwi2_conda_result/Subj016_time2_S14_metaphlan.txt', 'gmwi2_conda_result/Subj020_time1_S15_metaphlan.txt', 'gmwi2_conda_result/Subj011_time2_S9_metaphlan.txt', 'gmwi2_conda_result/Subj045_time1_S35_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj013_time1_S10_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj040_time1_S29_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj017_time1_ReExtract_S44_GMWI2.txt', 'gmwi2_conda_result/Subj039_time2_S28_GMWI2.txt', 'gmwi2_conda_result/Subj052_time1_S37_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj007_time1_S5_metaphlan.txt', 'gmwi2_conda_result/Subj003_time1_S3_metaphlan.txt', 'gmwi2_conda_result/Subj042_time1_S31_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj003_time1_S3_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj034_time2_S25_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj045_time1_S35_metaphlan.txt', 'gmwi2_conda_result/Subj011_time2_S9_GMWI2.txt', 'gmwi2_conda_result/Subj008_time2_S7_metaphlan.txt', 'gmwi2_conda_result/Subj008_time2_S7_GMWI2.txt', 'gmwi2_conda_result/Subj015_time2_S12_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj017_time1_ReExtract_S44_metaphlan.txt', 'gmwi2_conda_result/Subj049_time1_S36_metaphlan.txt', 'gmwi2_conda_result/Subj043_time2_S33_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj044_time1_S34_metaphlan.txt', 'gmwi2_conda_result/Subj040_time1_S29_metaphlan.txt', 'gmwi2_conda_result/Subj016_time1_S13_GMWI2.txt', 'gmwi2_conda_result/Subj020_time1_S15_GMWI2.txt', 'gmwi2_conda_result/Subj052_time1_S37_GMWI2.txt', 'gmwi2_conda_result/Subj015_time2_S12_GMWI2.txt', 'gmwi2_conda_result/Subj045_time1_S35_GMWI2.txt', 'gmwi2_conda_result/Subj001_time2_S2_GMWI2.txt', 'gmwi2_conda_result/Subj032_time1_S22_metaphlan.txt', 'gmwi2_conda_result/Subj030_time1_S18_metaphlan.txt', 'gmwi2_conda_result/Subj054_time2_S42_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj049_time1_S36_GMWI2.txt', 'gmwi2_conda_result/Subj043_time1_S32_GMWI2.txt', 'gmwi2_conda_result/Subj021_time1_S16_GMWI2.txt', 'gmwi2_conda_result/Subj054_time3_S43_metaphlan.txt', 'gmwi2_conda_result/Subj031_time1_S21_GMWI2.txt', 'gmwi2_conda_result/Subj035_time1_S26_GMWI2.txt', 'gmwi2_conda_result/Subj016_time1_S13_metaphlan.txt', 'gmwi2_conda_result/Subj001_time1_S1_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj003_time1_S3_GMWI2.txt', 'gmwi2_conda_result/Subj014_time1_S11_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj043_time2_S33_GMWI2.txt', 'gmwi2_conda_result/Subj001_time2_S2_metaphlan.txt', 'gmwi2_conda_result/Subj031_time1_S21_metaphlan.txt', 'gmwi2_conda_result/Subj030_time3_S20_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj032_time2_S23_metaphlan.txt', 'gmwi2_conda_result/Subj054_time1_S41_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj043_time2_S33_metaphlan.txt', 'gmwi2_conda_result/Subj054_time2_S42_metaphlan.txt', 'gmwi2_conda_result/Subj030_time2_S19_metaphlan.txt', 'gmwi2_conda_result/Subj020_time1_S15_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj014_time1_S11_GMWI2.txt', 'gmwi2_conda_result/Subj007_time1_S5_GMWI2.txt', 'gmwi2_conda_result/Subj053_time2_S40_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj015_time2_S12_metaphlan.txt', 'gmwi2_conda_result/Subj044_time1_S34_GMWI2.txt', 'gmwi2_conda_result/Subj008_time1_S6_metaphlan.txt', 'gmwi2_conda_result/Subj053_time1_S39_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj049_time1_S36_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj030_time3_S20_GMWI2.txt', 'gmwi2_conda_result/Subj039_time2_S28_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj032_time2_S23_GMWI2.txt', 'gmwi2_conda_result/Subj011_time2_S9_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj042_time1_S31_metaphlan.txt', 'gmwi2_conda_result/Subj031_time1_S21_GMWI2_taxa.txt', 'gmwi2_conda_result/Subj008_time1_S6_GMWI2_taxa.txt', 'gmwi2_conda_result/Sub ...

# %%
pd.DataFrame(gmwi2, index=["GMWI2"]).T.sort_index()

# %%
results.to_csv(os.path.join(config.LOG_DIR, "kefir_results.csv"))

# %%
time = [t.split("_")[1] for t in results.index]
subject = [t.split("_")[0] for t in results.index]

results["time"] = time
results["subject"] = subject

# %%
results = results[results["time"] != "time3"]
results
# Out:
#                                      GMWI2      GMWI   time  subject
# Subj015_time2_S12_metaphlan3.txt  0.067174  0.300616  time2  Subj015

# %%
from scipy.stats import wilcoxon

# %%
count = results.groupby("subject").count()
in_both = count[count["time"] == 2].index

# %%
wilc_df = results[results["subject"].isin(in_both)]

# %%
import matplotlib.pyplot as plt

wilcoxon(wilc_df[wilc_df["time"] == "time1"]["GMWI2"], wilc_df[wilc_df["time"] == "time2"]["GMWI2"], alternative='less')
# Out:
# WilcoxonResult(statistic=nan, pvalue=nan)

# %%
wilcoxon(wilc_df[wilc_df["time"] == "time1"]["GMWI"], wilc_df[wilc_df["time"] == "time2"]["GMWI"], alternative='less')
# Out:
# WilcoxonResult(statistic=nan, pvalue=nan)

# %%
def compute_GMWI(file):
    df = pd.read_csv(file, sep="\t", skiprows=3, usecols=[0, 2], index_col=0).T

    # load model
    gmwi = load(os.path.join(config.MODEL_DIR, "GMHI_model.joblib"))

    # add dummy columns
    dummy_cols = list(set(gmwi.features) - set(df.columns))
    
    dummy_df = pd.DataFrame(np.zeros((1, len(dummy_cols))), columns=dummy_cols, index=["relative_abundance"])
    df = pd.concat([dummy_df, df], axis=1)
    df = df.copy()[["UNKNOWN"] + list(gmwi.features)]

    # normalize relative abundances
    df = df.divide((100 - df["UNKNOWN"]), axis="rows")
    df = df.drop(labels=["UNKNOWN"], axis=1)

    # compute gmwi
    score = gmwi.decision_function(df)[0]
    return score

# %%
data_dir = "../data/raw/kefir_metaphlan3_results/gmwi2_conda_result"
gmwi = {}

for f in os.listdir(data_dir):
    if "metaphlan" not in f: continue
    score = compute_GMWI(os.path.join(data_dir, f))
    gmwi[f[:-14]] = score

# %%
gmwi
# Out:
# {'Subj007_time1_S5': -0.8888195604071943,
#  'Subj032_time2_S23': 2.8365366905016045,
#  'Subj015_time2_S12': 0.3657219827621851,
#  'Subj049_time1_S36': -0.787828500416479,
#  'Subj043_time2_S33': 2.346656051860808,
#  'Subj044_time1_S34': -1.0374381532800967,
#  'Subj042_time1_S31': -0.7547451539646592,
#  'Subj054_time3_S43': -0.35042509194738974,
#  'Subj034_time2_S25': 0.18107004345464026,
#  'Subj039_time1_S27': 2.1319701495832586,
#  'Subj017_time1_ReExtract_S44': -0.4076396821578574,
#  'Subj053_time1_S39': -0.7450549540519847,
#  'Subj008_time2_S7': 0.20974114107110786,
#  'Subj021_time2_S17': 1.3614549014478594,
#  'Subj020_time1_S15': 2.2867302560011713,
#  'Subj045_time1_S35': -0.3974582424036626,
#  'Subj040_time1_S29': 0.365572010812012,
#  'Subj001_time1_S1': -0.18667413762274887,
#  'Subj008_time1_S6': -0.2376271445062431,
#  'Subj013_time1_S10': -1.37715639337964,
#  'Subj052_time2_S38': 0.3164815638075014,
#  'Subj030_time1_S18': -0.6299343865936748,
#  'Subj053_time2_S40': 2.967349451067299,
#  'Subj032_time1_S22': 2.860112257277506,
#  'Subj001_time2_S2': 1.5172086340505833,
#  'Subj052_time1_S37': -0.7945937546829903,
#  'Subj016_time2_S14': 1.592817782783496,
#  'Subj011_time1_S8': -3.786068518698005,
#  'Subj054_time1_S41': -0.2555892224024525,
#  'Subj011_time2_S9': 2.692034927953472,
#  'Subj041_time1_S30': -2.7097919221573314,
#  'Subj034_time1_S24': -1.6947232645211265,
#  'Subj039_time2_S28': 3.0012653325736443,
#  'Subj043_time1_S32': 0.9640156507308585,
#  'Subj031_time1_S21': -0.7990038058674334,
#  'Subj014_time1_S11': -2.7801317920557693,
#  'Subj030_time3_S20': 0.8714231228741658,
#  'Subj035_time1_S26': -0.5916726739718596,
#  'Subj016_time1_S13': -0.31249138344747796,
#  'Subj004_time1_S4': -1.018247101846051,
#  'Subj021_time1_S16': 1.704075619930968,
#  'Subj003_time1_S3': 0.23324210194464975,
#  'Subj030_time2_S19': -0.9789395591979565,
#  'Subj054_time2_S42': -0.28184011286591437}

# %%
data_dir = "../data/raw/kefir_metaphlan3_results/gmwi2_conda_result"
gmwi2 = {}
for f in os.listdir(data_dir):
    dir_ = data_dir + "/" + f
    if "GMWI2.txt" not in f: continue
    with open(dir_) as file:
        score = float(file.read())
    gmwi2[f[:-10]] = score

# %%
results = pd.DataFrame([gmwi], index=["GMWI"]).T.sort_index()
results
# Out:
#                                  GMWI
# Subj001_time1_S1            -0.186674
# Subj001_time2_S2             1.517209
# Subj003_time1_S3             0.233242
# Subj004_time1_S4            -1.018247
# Subj007_time1_S5            -0.888820
# Subj008_time1_S6            -0.237627
# Subj008_time2_S7             0.209741
# Subj011_time1_S8            -3.786069
# Subj011_time2_S9             2.692035
# Subj013_time1_S10           -1.377156
# Subj014_time1_S11           -2.780132
# Subj015_time2_S12            0.365722
# Subj016_time1_S13           -0.312491
# Subj016_time2_S14            1.592818
# Subj017_time1_ReExtract_S44 -0.407640
# Subj020_time1_S15            2.286730
# Subj021_time1_S16            1.704076
# Subj021_time2_S17            1.361455
# Subj030_time1_S18           -0.629934
# Subj030_time2_S19           -0.978940
# Subj030_time3_S20            0.871423
# Subj031_time1_S21           -0.799004
# Subj032_time1_S22            2.860112
# Subj032_time2_S23            2.836537
# Subj034_time1_S24           -1.694723
# Subj034_time2_S25            0.181070
# Subj035_time1_S26           -0.591673
# Subj039_time1_S27            2.131970
# Subj039_time2_S28            3.001265
# Subj040_time1_S29            0.365572
# Subj041_time1_S30           -2.709792
# Subj042_time1_S31           -0.754745
# Subj043_time1_S32            0.964016
# Subj043_time2_S33            2.346656
# Subj044_time1_S34           -1.037438
# Subj045_time1_S35           -0.397458
# Subj049_time1_S36           -0.787829
# Subj052_time1_S37           -0.794594
# Subj052_time2_S38            0.316482
# Subj053_time1_S39           -0.745055
# Subj053_time2_S40            2.967349
# Subj054_time1_S41           -0.255589
# Subj054_time2_S42           -0.281840
# Subj054_time3_S43           -0.350425

# %%
results.to_csv(os.path.join(config.LOG_DIR, "kefir_results.csv"))
