# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import os
import config
from joblib import dump, load

# %%
gmhi2 = load(os.path.join(config.MODEL_DIR, "gmhi2_model.joblib"))
gmhi2
# Out:
# LogisticRegression(C=0.03, class_weight='balanced', penalty='l1',
#                    random_state=42, solver='liblinear')

# %% [markdown]
# # Load data

# %%
X = pd.read_csv(os.path.join(config.CLEAN_DIR, "taxonomic_features_test.csv"), index_col=[0])
X.head()
# Out:
#             k__Archaea  k__Archaea|p__Euryarchaeota  \
# Sample_ID
# ERR3472476    0.000000                     0.000000
# ERR3472477    0.000000                     0.000000
# ERR3472478    0.001191                     0.001191
# ERR3472479    0.000000                     0.000000
# ERR3472480    0.000000                     0.000000
#
#             k__Archaea|p__Euryarchaeota|c__Methanobacteria  \
# Sample_ID
# ERR3472476                                        0.000000
# ERR3472477                                        0.000000
# ERR3472478                                        0.001191
# ERR3472479                                        0.000000
# ERR3472480                                        0.000000
#
#             k__Archaea|p__Euryarchaeota|c__Methanobacteria|o__Methanobacteriales  \
# Sample_ID
# ERR3472476                                           0.000000
# ERR3472477                                           0.000000
# ...

# %% [markdown]
# # Compute scores and save

# %%
output = pd.DataFrame(gmhi2.decision_function(X > config.PRESENCE_CUTOFF), index=X.index, columns=["GMHI2_score"])
output
# Out:
#             GMHI2_score
# Sample_ID
# ERR3472476     0.000002
# ERR3472477    -0.191481
# ERR3472478    -0.434721
# ERR3472479     0.572428
# ERR3472480     0.189920
# ...                 ...
# 76502-0036     1.483486
# 76502-0038     0.589462
# 76502-0039     1.458575
# 76502-0040     0.496505
# 76502-0043     1.136953
#
# [5630 rows x 1 columns]

# %%
output.to_csv(os.path.join(config.LOG_DIR, "GMHI2_scores_test_set.csv"))
