# %% [markdown]
# # Import libraries

# %%
import pandas as pd
from config import RAW_DIR, CLEAN_DIR, FIG_DATA_DIR
import numpy as np
import os

# %%
files = [
"FL24_1_metaphlan3.txt",
"XS24_2_metaphlan3.txt",
"XS24_3_metaphlan3.txt",
"FS24_3_metaphlan3.txt",
"NS0_3_metaphlan3.txt",
"FS24_2_metaphlan3.txt",
"NS24_1_metaphlan3.txt",
"NS0_2_metaphlan3.txt",
"IN24_2_metaphlan3.txt",
"GS24_2_metaphlan3.txt",
"IN24_3_metaphlan3.txt",
"GS24_3_metaphlan3.txt",
"FL24_3_metaphlan3.txt",
"FL24_2_metaphlan3.txt",
"XS24_1_metaphlan3.txt",
"NS24_3_metaphlan3.txt",
"NS0_1_metaphlan3.txt",
"FS24_1_metaphlan3.txt",
"NS24_2_metaphlan3.txt",
"GS24_1_metaphlan3.txt",
"IN24_1_metaphlan3.txt",
]

# %%
files = [os.path.join(RAW_DIR, "prebiotics", f) for f in files]

# %%
dataframes = []

for file in files:
    name = file.split("/")[-1].split("_metaphlan3.txt")[0]
    df = pd.read_csv(file, sep="\t", skiprows=3, index_col=0, usecols=["#clade_name", "relative_abundance"])
    df.columns = [name]
    dataframes.append(df)

# %%
dataframes
# Out:
# [                                                       FL24_1
#  #clade_name
#  UNKNOWN                                             20.581250
#  k__Bacteria                                         77.780903
#  k__Viruses                                           1.637845
#  k__Bacteria|p__Bacteroidetes                        33.118492
#  k__Bacteria|p__Actinobacteria                       18.335939
#  ...                                                       ...
#  k__Bacteria|p__Proteobacteria|c__Gammaproteobac...   0.000516
#  k__Bacteria|p__Synergistetes|c__Synergistia|o__...   0.000508
#  k__Bacteria|p__Proteobacteria|c__Gammaproteobac...   0.000508
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000469
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000421
#
#  [310 rows x 1 columns],
#                                                         XS24_2
#  #clade_name
#  UNKNOWN                                             26.891080
#  k__Bacteria                                         72.969542
#  k__Viruses                                           0.139382
#  k__Bacteria|p__Bacteroidetes                        28.337487
#  k__Bacteria|p__Proteobacteria                       16.836400
#  ...                                                       ...
#  k__Bacteria|p__Actinobacteria|c__Actinobacteria...   0.000760
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000629
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000629
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000358
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000110
#
#  [321 rows x 1 columns],
#                                                         XS24_3
#  #clade_name
#  UNKNOWN                                             26.242600
#  k__Bacteria                                         73.640800
#  k__Viruses                                           0.116596
#  k__Bacteria|p__Bacteroidetes                        28.734318
#  k__Bacteria|p__Proteobacteria                       16.920721
#  ...                                                       ...
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000553
#  k__Bacteria|p__Proteobacteria|c__Betaproteobact...   0.000509
#  k__Bacteria|p__Actinobacteria|c__Actinobacteria...   0.000361
#  k__Bacteria|p__Proteobacteria|c__Gammaproteobac...   0.000332
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000310
#
#  [326 rows x 1 columns],
#                                                         FS24_3
#  #clade_name
#  UNKNOWN                                             28.558080
#  k__Bacteria                                         70.556079
#  k__Viruses                                           0.885844
#  k__Bacteria|p__Bacteroidetes                        24.783982
#  k__Bacteria|p__Firmicutes                           15.393448
#  ...                                                       ...
#  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o__...   0.001400
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.001400
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.001207
#  k__Bacteria|p__Proteobacteria|c__Gammaproteobac...   0.000564
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000400
#
#  [306 rows x 1 columns],
#                                                          NS0_3
#  #clade_name
#  UNKNOWN                                             40.880450
#  k__Bacteria                                         59.067947
#  k__Viruses                                           0.048171
#  k__Archaea                                           0.003429
#  k__Bacteria|p__Firmicutes                           37.520232
#  ...                                                       ...
#  k__Bacteria|p__Actinobacteria|c__Actinobacteria...   0.000473
#  k__Bacteria|p__Firmicutes|c__Negativicutes|o__V...   0.000396
#  k__Bacteria|p__Firmicutes|c__Negativicutes|o__V...   0.000372
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000372
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000225
#
#  [366 rows x 1 columns],
#                                                         FS24_2
#  #clade_name
#  UNKNOWN                                             28.629500
#  k__Bacteria                                         70.361040
#  k__Viruses                                           1.009464
#  k__Bacteria|p__Bacteroidetes                        24.434770
#  k__Bacteria|p__Firmicutes                           15.296476
#  ...                                                       ...
#  k__Bacteria|p__Synergistetes|c__Synergistia|o__...   0.000921
#  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o__...   0.000878
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000871
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000749
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000671
#
#  [305 rows x 1 columns],
#                                                         NS24_1
#  #clade_name
#  UNKNOWN                                             18.860020
#  k__Bacteria                                         81.080191
#  k__Viruses                                           0.059792
#  k__Bacteria|p__Proteobacteria                       37.470379
#  k__Bacteria|p__Bacteroidetes                        25.214444
#  ...                                                       ...
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000487
#  k__Bacteria|p__Proteobacteria|c__Betaproteobact...   0.000462
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000446
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000260
#  k__Bacteria|p__Proteobacteria|c__Deltaproteobac...   0.000146
#
#  [305 rows x 1 columns],
#                                                          NS0_2
#  #clade_name
#  UNKNOWN                                             40.735680
#  k__Bacteria                                         59.199504
#  k__Viruses                                           0.059211
#  k__Archaea                                           0.005606
#  k__Bacteria|p__Firmicutes                           37.432074
#  ...                                                       ...
#  k__Bacteria|p__Actinobacteria|c__Actinobacteria...   0.000687
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000539
#  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o__...   0.000516
#  k__Bacteria|p__Actinobacteria|c__Actinobacteria...   0.000397
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000249
#
#  [361 rows x 1 columns],
#                                                         IN24_2
#  #clade_name
#  UNKNOWN                                             26.695360
#  k__Bacteria                                         73.108640
#  k__Viruses                                           0.196002
#  k__Bacteria|p__Bacteroidetes                        36.642278
#  k__Bacteria|p__Proteobacteria                       13.192167
#  ...                                                       ...
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000425
#  k__Bacteria|p__Proteobacteria|c__Gammaproteobac...   0.000337
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000235
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000117
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000103
#
#  [320 rows x 1 columns],
#                                                         GS24_2
#  #clade_name
#  UNKNOWN                                             15.891420
#  k__Bacteria                                         84.067791
#  k__Viruses                                           0.040793
#  k__Bacteria|p__Bacteroidetes                        32.190054
#  k__Bacteria|p__Proteobacteria                       29.027336
#  ...                                                       ...
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000690
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000555
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000547
#  k__Bacteria|p__Firmicutes|c__Erysipelotrichia|o...   0.000437
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000387
#
#  [277 rows x 1 columns],
#                                                         IN24_3
#  #clade_name
#  UNKNOWN                                             26.326470
#  k__Bacteria                                         73.179105
#  k__Viruses                                           0.494423
#  k__Bacteria|p__Bacteroidetes                        36.979639
#  k__Bacteria|p__Proteobacteria                       13.355427
#  ...                                                       ...
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000494
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000442
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000317
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000228
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000118
#
#  [323 rows x 1 columns],
#                                                         GS24_3
#  #clade_name
#  UNKNOWN                                             14.938650
#  k__Bacteria                                         85.061352
#  k__Bacteria|p__Bacteroidetes                        32.331080
#  k__Bacteria|p__Proteobacteria                       30.156206
#  k__Bacteria|p__Actinobacteria                        9.411792
#  ...                                                       ...
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000451
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000425
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000374
#  k__Bacteria|p__Firmicutes|c__Erysipelotrichia|o...   0.000298
#  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o__...   0.000128
#
#  [268 rows x 1 columns],
#                                                         FL24_3
#  #clade_name
#  UNKNOWN                                             21.858010
#  k__Bacteria                                         76.394396
#  k__Viruses                                           1.747591
#  k__Bacteria|p__Bacteroidetes                        30.719373
#  k__Bacteria|p__Actinobacteria                       19.356091
#  ...                                                       ...
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000359
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000297
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000266
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000195
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000109
#
#  [315 rows x 1 columns],
#                                                         FL24_2
#  #clade_name
#  UNKNOWN                                             21.634480
#  k__Bacteria                                         76.797045
#  k__Viruses                                           1.568478
#  k__Bacteria|p__Bacteroidetes                        29.866974
#  k__Bacteria|p__Actinobacteria                       19.977237
#  ...                                                       ...
#  k__Bacteria|p__Proteobacteria|c__Betaproteobact...   0.000423
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000400
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000368
#  k__Bacteria|p__Synergistetes|c__Synergistia|o__...   0.000243
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000227
#
#  [318 rows x 1 columns],
#                                                         XS24_1
#  #clade_name
#  UNKNOWN                                             26.488490
#  k__Bacteria                                         73.402694
#  k__Viruses                                           0.108819
#  k__Bacteria|p__Bacteroidetes                        29.293868
#  k__Bacteria|p__Proteobacteria                       16.678292
#  ...                                                       ...
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.001044
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000970
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000963
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000904
#  k__Bacteria|p__Proteobacteria|c__Gammaproteobac...   0.000772
#
#  [322 rows x 1 columns],
#                                                         NS24_3
#  #clade_name
#  UNKNOWN                                             18.745350
#  k__Bacteria                                         81.203565
#  k__Viruses                                           0.051085
#  k__Bacteria|p__Proteobacteria                       37.754071
#  k__Bacteria|p__Bacteroidetes                        24.994141
#  ...                                                       ...
#  k__Bacteria|p__Proteobacteria|c__Betaproteobact...   0.001032
#  k__Bacteria|p__Proteobacteria|c__Betaproteobact...   0.000943
#  k__Bacteria|p__Firmicutes|c__Negativicutes|o__V...   0.000463
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000276
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000203
#
#  [312 rows x 1 columns],
#                                                          NS0_1
#  #clade_name
#  UNKNOWN                                             40.796450
#  k__Bacteria                                         59.138908
#  k__Viruses                                           0.063673
#  k__Archaea                                           0.000965
#  k__Bacteria|p__Firmicutes                           37.407447
#  ...                                                       ...
#  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o__...   0.000693
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000551
#  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o__...   0.000485
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000326
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000314
#
#  [376 rows x 1 columns],
#                                                         FS24_1
#  #clade_name
#  UNKNOWN                                             28.628920
#  k__Bacteria                                         70.756207
#  k__Viruses                                           0.614869
#  k__Bacteria|p__Bacteroidetes                        24.974488
#  k__Bacteria|p__Firmicutes                           15.519019
#  ...                                                       ...
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000849
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000806
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000649
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000400
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000278
#
#  [307 rows x 1 columns],
#                                                         NS24_2
#  #clade_name
#  UNKNOWN                                             18.628730
#  k__Bacteria                                         81.360533
#  k__Viruses                                           0.010733
#  k__Bacteria|p__Proteobacteria                       38.198447
#  k__Bacteria|p__Bacteroidetes                        24.809619
#  ...                                                       ...
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000342
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000293
#  k__Bacteria|p__Actinobacteria|c__Actinobacteria...   0.000260
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000244
#  k__Bacteria|p__Firmicutes|c__Tissierellia|o__Ti...   0.000163
#
#  [298 rows x 1 columns],
#                                                         GS24_1
#  #clade_name
#  UNKNOWN                                             15.858840
#  k__Bacteria                                         84.113852
#  k__Viruses                                           0.027312
#  k__Bacteria|p__Bacteroidetes                        32.924404
#  k__Bacteria|p__Proteobacteria                       28.460681
#  ...                                                       ...
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000783
#  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o__...   0.000395
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000286
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000278
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000210
#
#  [273 rows x 1 columns],
#                                                         IN24_1
#  #clade_name
#  UNKNOWN                                             26.489920
#  k__Bacteria                                         73.091245
#  k__Viruses                                           0.418838
#  k__Bacteria|p__Bacteroidetes                        37.412560
#  k__Bacteria|p__Proteobacteria                       12.946192
#  ...                                                       ...
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000559
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000507
#  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clos...   0.000500
#  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactoba...   0.000353
#  k__Bacteria|p__Actinobacteria|c__Coriobacteriia...   0.000294
#
#  [311 rows x 1 columns]]

# %%
concat_df = pd.concat(dataframes, axis=1).fillna(0).T
concat_df
# Out:
# #clade_name   UNKNOWN  k__Bacteria  k__Viruses  k__Bacteria|p__Bacteroidetes  \
# FL24_1       20.58125    77.780903    1.637845                     33.118492
# XS24_2       26.89108    72.969542    0.139382                     28.337487
# XS24_3       26.24260    73.640800    0.116596                     28.734318
# FS24_3       28.55808    70.556079    0.885844                     24.783982
# NS0_3        40.88045    59.067947    0.048171                     17.065111
# FS24_2       28.62950    70.361040    1.009464                     24.434770
# NS24_1       18.86002    81.080191    0.059792                     25.214444
# NS0_2        40.73568    59.199504    0.059211                     17.300636
# IN24_2       26.69536    73.108640    0.196002                     36.642278
# GS24_2       15.89142    84.067791    0.040793                     32.190054
# IN24_3       26.32647    73.179105    0.494423                     36.979639
# GS24_3       14.93865    85.061352    0.000000                     32.331080
# FL24_3       21.85801    76.394396    1.747591                     30.719373
# FL24_2       21.63448    76.797045    1.568478                     29.866974
# XS24_1       26.48849    73.402694    0.108819                     29.293868
# NS24_3       18.74535    81.203565    0.051085                     24.994141
# NS0_1        40.79645    59.138908    0.063673                     17.592938
# FS24_1       28.62892    70.756207    0.614869                     24.974488
# NS24_2       18.62873    81.360533    0.010733                     24.809619
# GS24_1       15.85884    84.113852    0.027312                     32.924404
# IN24_1       26.48992    73.091245    0.418838                     37.412560
#
# #clade_name  k__Bacteria|p__Actinobacteria  k__Bacteria|p__Proteobacteria  \
# FL24_1                           18.335939                      11.576220
# XS24_2                            7.453535                      16.836400
# XS24_3                            7.034486                      16.920721
# FS24_3                           11.577478                      11.636432
# NS0_3                             3.506392                       0.966995
# FS24_2                           11.658022                      11.989010
# NS24_1                            1.291456                      37.470379
# NS0_2                             3.387620                       1.071564
# IN24_2                            8.406672                      13.192167
# GS24_2                            9.342117                      29.027336
# IN24_3                            7.900565                      13.355427
# GS24_3                            9.411792                      30.156206
# FL24_3                           19.356091                      12.015339
# FL24_2                           19.977237                      13.021270
# XS24_1                            6.890418                      16.678292
# NS24_3                            1.466443                      37.754071
# NS0_1                             3.264768                       0.869730
# FS24_1                           11.148076                      11.918484
# NS24_2                            1.406454                      38.198447
# GS24_1                            9.070384                      28.460681
# IN24_1                            7.351420                      12.946192
#
# #clade_name  k__Bacteria|p__Firmicutes  k__Bacteria|p__Fusobacteria  \
# FL24_1                        8.764335                     5.980812
# XS24_2                       14.762593                     5.488185
# XS24_3                       15.192408                     5.679039
# FS24_3                       15.393448                     7.149336
# NS0_3                        37.520232                     0.001377
# FS24_2                       15.296476                     6.969258
# NS24_1                       10.801590                     6.296519
# NS0_2                        37.432074                     0.000000
# IN24_2                        9.893392                     4.967628
# GS24_2                        9.414568                     4.092042
# IN24_3                        9.979684                     4.957801
# GS24_3                        9.082137                     4.078734
# FL24_3                        8.527651                     5.769778
# FL24_2                        8.418189                     5.508281
# XS24_1                       14.785819                     5.673405
# NS24_3                       10.850478                     6.132142
# NS0_1                        37.407447                     0.000000
# FS24_1                       15.519019                     7.184869
# NS24_2                       10.751642                     6.190474
# GS24_1                        9.358550                     4.297072
# IN24_1                       10.231045                     5.142795
#
# #clade_name  k__Viruses|p__Viruses_unclassified  \
# FL24_1                                 1.637845
# XS24_2                                 0.139382
# XS24_3                                 0.116596
# FS24_3                                 0.885844
# NS0_3                                  0.048171
# FS24_2                                 1.009464
# NS24_1                                 0.059792
# NS0_2                                  0.059211
# IN24_2                                 0.196002
# GS24_2                                 0.040793
# IN24_3                                 0.494423
# GS24_3                                 0.000000
# FL24_3                                 1.747591
# FL24_2                                 1.568478
# XS24_1                                 0.108819
# NS24_3                                 0.051085
# NS0_1                                  0.063673
# FS24_1                                 0.614869
# NS24_2                                 0.010733
# GS24_1                                 0.027312
# IN24_1                                 0.418838
#
# #clade_name  k__Bacteria|p__Verrucomicrobia  ...  \
# FL24_1                             0.004598  ...
# XS24_2                             0.089515  ...
# XS24_3                             0.076700  ...
# FS24_3                             0.005937  ...
# NS0_3                              0.000000  ...
# FS24_2                             0.006523  ...
# NS24_1                             0.000000  ...
# NS0_2                              0.000000  ...
# IN24_2                             0.003255  ...
# GS24_2                             0.000000  ...
# IN24_3                             0.002895  ...
# GS24_3                             0.000791  ...
# FL24_3                             0.005032  ...
# FL24_2                             0.004859  ...
# XS24_1                             0.078665  ...
# NS24_3                             0.000000  ...
# NS0_1                              0.000000  ...
# FS24_1                             0.004218  ...
# NS24_2                             0.000000  ...
# GS24_1                             0.001666  ...
# IN24_1                             0.003271  ...
#
# #clade_name  k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Caudovirales|f__Siphoviridae|g__Sfi21dt1virus|s__Streptococcus_virus_phiAbc2  \
# FL24_1                                                0.000000
# XS24_2                                                0.000000
# XS24_3                                                0.000000
# FS24_3                                                0.000000
# NS0_3                                                 0.000000
# FS24_2                                                0.000000
# NS24_1                                                0.000000
# NS0_2                                                 0.000000
# IN24_2                                                0.000000
# GS24_2                                                0.000000
# IN24_3                                                0.000000
# GS24_3                                                0.000000
# FL24_3                                                0.000000
# FL24_2                                                0.000000
# XS24_1                                                0.000000
# NS24_3                                                0.000000
# NS0_1                                                 0.010941
# FS24_1                                                0.000000
# NS24_2                                                0.000000
# GS24_1                                                0.000000
# IN24_1                                                0.000000
#
# #clade_name  k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Caudovirales|f__Myoviridae|g__Myoviridae_unclassified|s__Cronobacter_phage_ENT47670  \
# FL24_1                                                0.000000
# XS24_2                                                0.000000
# XS24_3                                                0.000000
# FS24_3                                                0.000000
# NS0_3                                                 0.000000
# FS24_2                                                0.000000
# NS24_1                                                0.000000
# NS0_2                                                 0.000000
# IN24_2                                                0.000000
# GS24_2                                                0.000000
# IN24_3                                                0.000000
# GS24_3                                                0.000000
# FL24_3                                                0.000000
# FL24_2                                                0.000000
# XS24_1                                                0.000000
# NS24_3                                                0.000000
# NS0_1                                                 0.006098
# FS24_1                                                0.000000
# NS24_2                                                0.000000
# GS24_1                                                0.000000
# IN24_1                                                0.000000
#
# #clade_name  k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Caudovirales|f__Siphoviridae|g__Siphoviridae_unclassified|s__Lactobacillus_phage_Sha1  \
# FL24_1                                                0.000000
# XS24_2                                                0.000000
# XS24_3                                                0.000000
# FS24_3                                                0.000000
# NS0_3                                                 0.000000
# FS24_2                                                0.000000
# NS24_1                                                0.000000
# NS0_2                                                 0.000000
# IN24_2                                                0.000000
# GS24_2                                                0.000000
# IN24_3                                                0.000000
# GS24_3                                                0.000000
# FL24_3                                                0.000000
# FL24_2                                                0.000000
# XS24_1                                                0.000000
# NS24_3                                                0.000000
# NS0_1                                                 0.004464
# FS24_1                                                0.000000
# NS24_2                                                0.000000
# GS24_1                                                0.000000
# IN24_1                                                0.000000
#
# #clade_name  k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Caudovirales|f__Siphoviridae|g__Sfi21dt1virus|s__Streptococcus_virus_7201  \
# FL24_1                                                 0.00000
# XS24_2                                                 0.00000
# XS24_3                                                 0.00000
# FS24_3                                                 0.00000
# NS0_3                                                  0.00000
# FS24_2                                                 0.00000
# NS24_1                                                 0.00000
# NS0_2                                                  0.00000
# IN24_2                                                 0.00000
# GS24_2                                                 0.00000
# IN24_3                                                 0.00000
# GS24_3                                                 0.00000
# FL24_3                                                 0.00000
# FL24_2                                                 0.00000
# XS24_1                                                 0.00000
# NS24_3                                                 0.00000
# NS0_1                                                  0.00434
# FS24_1                                                 0.00000
# NS24_2                                                 0.00000
# GS24_1                                                 0.00000
# IN24_1                                                 0.00000
#
# #clade_name  k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Caudovirales|f__Siphoviridae|g__Siphoviridae_unclassified|s__Lactobacillus_phage_phig1e  \
# FL24_1                                                0.000000
# XS24_2                                                0.000000
# XS24_3                                                0.000000
# FS24_3                                                0.000000
# NS0_3                                                 0.000000
# FS24_2                                                0.000000
# NS24_1                                                0.000000
# NS0_2                                                 0.000000
# IN24_2                                                0.000000
# GS24_2                                                0.000000
# IN24_3                                                0.000000
# GS24_3                                                0.000000
# FL24_3                                                0.000000
# FL24_2                                                0.000000
# XS24_1                                                0.000000
# NS24_3                                                0.000000
# NS0_1                                                 0.003096
# FS24_1                                                0.000000
# NS24_2                                                0.000000
# GS24_1                                                0.000000
# IN24_1                                                0.000000
#
# #clade_name  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clostridiales|f__Clostridiaceae|g__Clostridium|s__Clostridium_bolteae_CAG_59  \
# FL24_1                                                0.000000
# XS24_2                                                0.000000
# XS24_3                                                0.000000
# FS24_3                                                0.000000
# NS0_3                                                 0.000000
# FS24_2                                                0.000000
# NS24_1                                                0.000000
# NS0_2                                                 0.000000
# IN24_2                                                0.000000
# GS24_2                                                0.000000
# IN24_3                                                0.000000
# GS24_3                                                0.000000
# FL24_3                                                0.000000
# FL24_2                                                0.000000
# XS24_1                                                0.000000
# NS24_3                                                0.000000
# NS0_1                                                 0.003002
# FS24_1                                                0.000000
# NS24_2                                                0.000000
# GS24_1                                                0.000000
# IN24_1                                                0.000000
#
# #clade_name  k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Caudovirales|f__Siphoviridae|g__Siphoviridae_unclassified|s__Lactococcus_phage_bIL309  \
# FL24_1                                                0.000000
# XS24_2                                                0.000000
# XS24_3                                                0.000000
# FS24_3                                                0.000000
# NS0_3                                                 0.000000
# FS24_2                                                0.000000
# NS24_1                                                0.000000
# NS0_2                                                 0.000000
# IN24_2                                                0.000000
# GS24_2                                                0.000000
# IN24_3                                                0.000000
# GS24_3                                                0.000000
# FL24_3                                                0.000000
# FL24_2                                                0.000000
# XS24_1                                                0.000000
# NS24_3                                                0.000000
# NS0_1                                                 0.002013
# FS24_1                                                0.000000
# NS24_2                                                0.000000
# GS24_1                                                0.000000
# IN24_1                                                0.000000
#
# #clade_name  k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Bifidobacteriales|f__Bifidobacteriaceae|g__Gardnerella|s__Gardnerella_vaginalis  \
# FL24_1                                                0.000000
# XS24_2                                                0.000000
# XS24_3                                                0.000000
# FS24_3                                                0.000000
# NS0_3                                                 0.000000
# FS24_2                                                0.000000
# NS24_1                                                0.000000
# NS0_2                                                 0.000000
# IN24_2                                                0.000000
# GS24_2                                                0.000000
# IN24_3                                                0.000000
# GS24_3                                                0.000000
# FL24_3                                                0.000000
# FL24_2                                                0.000000
# XS24_1                                                0.000000
# NS24_3                                                0.000000
# NS0_1                                                 0.000752
# FS24_1                                                0.000000
# NS24_2                                                0.000000
# GS24_1                                                0.000000
# IN24_1                                                0.000000
#
# #clade_name  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o__Bacteroidales|f__Prevotellaceae|g__Prevotella|s__Prevotella_stercorea  \
# FL24_1                                                0.000000
# XS24_2                                                0.000000
# XS24_3                                                0.000000
# FS24_3                                                0.000000
# NS0_3                                                 0.000000
# FS24_2                                                0.000000
# NS24_1                                                0.000000
# NS0_2                                                 0.000000
# IN24_2                                                0.000000
# GS24_2                                                0.000000
# IN24_3                                                0.000000
# GS24_3                                                0.000000
# FL24_3                                                0.000000
# FL24_2                                                0.000000
# XS24_1                                                0.000000
# NS24_3                                                0.000000
# NS0_1                                                 0.000485
# FS24_1                                                0.000000
# NS24_2                                                0.000000
# GS24_1                                                0.000000
# IN24_1                                                0.000000
#
# #clade_name  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clostridiales|f__Ruminococcaceae|g__Pseudoflavonifractor|s__Pseudoflavonifractor_sp_An184
# FL24_1                                                0.000000
# XS24_2                                                0.000000
# XS24_3                                                0.000000
# FS24_3                                                0.000000
# NS0_3                                                 0.000000
# FS24_2                                                0.000000
# NS24_1                                                0.000000
# NS0_2                                                 0.000000
# IN24_2                                                0.000000
# GS24_2                                                0.000000
# IN24_3                                                0.000000
# GS24_3                                                0.000000
# FL24_3                                                0.000000
# FL24_2                                                0.000000
# XS24_1                                                0.000000
# NS24_3                                                0.000000
# NS0_1                                                 0.000326
# FS24_1                                                0.000000
# NS24_2                                                0.000000
# GS24_1                                                0.000000
# IN24_1                                                0.000000
#
# [21 rows x 499 columns]

# %%
import pandas as pd
import numpy as np
import os
from joblib import dump, load
import config

gmhi2 = load(os.path.join(config.MODEL_DIR, "gmhi2_model.joblib"))
gmhi2
# Out:
# LogisticRegression(C=0.03, class_weight='balanced', penalty='l1',
#                    random_state=42, solver='liblinear')

# %%
concat_df = concat_df.divide((100 - concat_df["UNKNOWN"]), axis="rows")
concat_df = concat_df.drop(labels="UNKNOWN", axis=1)
concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
concat_df = concat_df.copy()[gmhi2.feature_names_in_]
# Out:
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# ...
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0
# /var/folders/w8/85y9rkfs49x53d7kk_ql70bc0000gn/T/ipykernel_50106/2652610923.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   concat_df[list(set(gmhi2.feature_names_in_) - set(concat_df.columns))] = 0

# %%
concat_df.sum(axis=1)
# Out:
# FL24_1    6.979377
# XS24_2    6.998361
# XS24_3    6.998570
# FS24_3    6.987663
# NS0_3     6.999186
# FS24_2    6.985968
# NS24_1    6.999786
# NS0_2     6.999001
# IN24_2    6.997327
# GS24_2    6.999837
# IN24_3    6.993470
# GS24_3    6.999998
# FL24_3    6.977635
# FL24_2    6.979943
# XS24_1    6.998710
# NS24_3    6.999751
# NS0_1     6.998761
# FS24_1    6.991555
# NS24_2    7.000000
# GS24_1    6.999834
# IN24_1    6.994398
# dtype: float64

# %%
output = pd.DataFrame(gmhi2.decision_function(concat_df > config.PRESENCE_CUTOFF), index=concat_df.index, columns=["GMHI2_score"])
# output = pd.DataFrame((concat_df > config.PRESENCE_CUTOFF).sum(axis=1), index=concat_df.index, columns=["GMHI2_score"])
output
# Out:
#         GMHI2_score
# FL24_1    -0.606819
# XS24_2     0.303276
# XS24_3     0.100174
# FS24_3     0.349678
# NS0_3      0.037727
# FS24_2     0.349678
# NS24_1    -0.177438
# NS0_2     -0.219505
# IN24_2     0.556352
# GS24_2     0.607876
# IN24_3     0.712718
# GS24_3     0.478390
# FL24_3    -0.567621
# FL24_2    -0.400289
# XS24_1     0.191774
# NS24_3    -0.340325
# NS0_1     -0.117391
# FS24_1     0.064687
# NS24_2    -0.177438
# GS24_1     0.610569
# IN24_1     0.725037

# %%
groups = ["NS0", "NS24", "FS24", "IN24", "GS24", "XS24", "FL24"]

# %%
group_values = {g : [float(output.loc[f"{g}_{i}"]) for i in range(1, 4)] for g in groups}

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from scipy.stats import sem

padding = [25, 20, 30, 18, 15, 18, 22]

plt.figure(figsize=(10, 8), dpi=200)

ax = plt.gca()

for i, g in enumerate(groups):
    color = "orange" if g.startswith("NS") else "steelblue"
    mean = np.mean(group_values[g])
    p = ax.bar(i, mean, color=color)
    plt.bar_label(p, label_type='edge', fmt="%.2f", padding=padding[i])
    
plt.axhline(y=0, color='black', linestyle='-')

legend_elements = [
    Patch(facecolor='orange', edgecolor='black', label='no substrate'),
    Patch(facecolor='steelblue', edgecolor='black', label='w/ prebiotic'),
                  ]

plt.legend(handles=legend_elements, loc=2)

y_vals = [np.mean(group_values[g]) for g in groups]
standard_errors = [sem(group_values[g]) for g in groups]

plt.errorbar(np.arange(len(groups)), y_vals, yerr=standard_errors, fmt="none", c="black", capsize=10)

plt.xticks(np.arange(len(groups)), groups)
plt.ylabel("GMWI2\n(Gut Microbiome Wellness Index 2)", fontsize=15)
# plt.ylim(-0.65, 0.85)

plt.savefig(os.path.join(config.FIGURE_DIR, "prebiotics.pdf"))
    
plt.show()

# %%
df = pd.DataFrame({"GMWI2": np.array([group_values[g] for g in groups]).flatten(), "Group" : np.array([[g, g, g] for g in groups]).flatten()})
df.to_csv("../data/raw/prebiotics_gmwi2.csv")

# %%
import statsmodels
import scipy

stat = scipy.stats.tukey_hsd(*[group_values[g] for g in groups])
print(stat)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)      0.132     0.779    -0.183     0.447
#  (0 - 2)     -0.354     0.023    -0.670    -0.039
#  (0 - 3)     -0.764     0.000    -1.080    -0.449
#  (0 - 4)     -0.665     0.000    -0.981    -0.350
#  (0 - 5)     -0.298     0.070    -0.614     0.017
#  (0 - 6)      0.425     0.006     0.110     0.741
#  (1 - 0)     -0.132     0.779    -0.447     0.183
#  (1 - 2)     -0.486     0.002    -0.802    -0.171
#  (1 - 3)     -0.896     0.000    -1.212    -0.581
#  (1 - 4)     -0.797     0.000    -1.113    -0.482
#  (1 - 5)     -0.430     0.005    -0.746    -0.115
#  (1 - 6)      0.293     0.076    -0.022     0.609
#  (2 - 0)      0.354     0.023     0.039     0.670
#  (2 - 1)      0.486     0.002     0.171     0.802
#  (2 - 3)     -0.410     0.008    -0.725    -0.095
#  (2 - 4)     -0.311     0.055    -0.626     0.005
#  (2 - 5)      0.056     0.995    -0.259     0.372
#  (2 - 6)      0.780     0.000     0.464     1.095
#  (3 - 0)      0.764     0.000     0.449     1.080
#  (3 - 1)      0.896     0.000     0.581     1.212
#  (3 - 2)      0.410     0.008     0.095     0.725
#  (3 - 4)      0.099     0.926    -0.216     0.415
#  (3 - 5)      0.466     0.003     0.151     0.782
#  (3 - 6)      1.190     0.000     0.874     1.505
#  (4 - 0)      0.665     0.000     0.350     0.981
#  (4 - 1)      0.797     0.000     0.482     1.113
#  (4 - 2)      0.311     0.055    -0.005     0.626
#  (4 - 3)     -0.099     0.926    -0.415     0.216
#  (4 - 5)      0.367     0.018     0.052     0.683
#  (4 - 6)      1.091     0.000     0.775     1.406
#  (5 - 0)      0.298     0.070    -0.017     0.614
#  (5 - 1)      0.430     0.005     0.115     0.746
#  (5 - 2)     -0.056     0.995    -0.372     0.259
#  (5 - 3)     -0.466     0.003    -0.782    -0.151
#  (5 - 4)     -0.367     0.018    -0.683    -0.052
#  (5 - 6)      0.723     0.000     0.408     1.039
#  (6 - 0)     -0.425     0.006    -0.741    -0.110
#  (6 - 1)     -0.293     0.076    -0.609     0.022
#  (6 - 2)     -0.780     0.000    -1.095    -0.464
#  (6 - 3)     -1.190     0.000    -1.505    -0.874
#  (6 - 4)     -1.091     0.000    -1.406    -0.775
#  (6 - 5)     -0.723     0.000    -1.039    -0.408

# %%
scipy.stats.ttest_ind(group_values["NS0"], group_values["XS24"])
# Out:
# Ttest_indResult(statistic=-3.135513089709021, pvalue=0.03499870571827718)

# %%
pd.DataFrame(group_values).T.to_csv(os.path.join(config.LOG_DIR, "prebiotics_GMWI2.csv"))
